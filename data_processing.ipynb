# %%
import os
import PyPDF2
import textract
import fitz

# %%
# Directories
notebooks_directory = "Lesson-Plans"
pdf_slides_directory = "Slides"
transcripts_directory = "Transcripts"
output_directory = "Output"

# %%
# Function to read markdown/code files
def extract_notebook_content(notebook_path, delimiter="##--CODE--##\n"):
    with open(notebook_path, 'r', encoding='utf-8') as nb_file:
        nb = nbformat.read(nb_file, as_version=4)
        combined_content = []
        for cell in nb.cells:
            if cell.cell_type == 'markdown':
                combined_content.append(cell.source)
            elif cell.cell_type == 'code':
                combined_content.append(delimiter + cell.source)
        return "\n\n".join(combined_content) + "\n\n"

def extract_md_content(md_path):
    with open(md_path, 'r', encoding='utf-8') as md_file:
        return md_file.read()

def extract_py_content(py_path):
    with open(py_path, 'r', encoding='utf-8') as py_file:
        return py_file.read()

def process_directory_and_combine(directory_path, output_directory, delimiter="##--CODE--##\n"):
    processed_files = 0
    skipped_files = 0
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if 'unsolved' in file.lower():  # Skip files with 'unsolved' in the filename (case insensitive)
                skipped_files += 1
                print(f"Skipped: {file}")
                continue  # Skip the rest of the loop for this file

            try:
                content = ""
                if file.endswith(".ipynb"):
                    content = extract_notebook_content(os.path.join(root, file), delimiter)
                elif file.endswith(".md"):
                    content = extract_md_content(os.path.join(root, file))
                elif file.endswith(".py"):
                    content = extract_py_content(os.path.join(root, file))
                else:
                    continue

                if content:
                    processed_files += 1
                    # Derive the subject name from the directory structure
                    subject_name = os.path.basename(os.path.dirname(root))
                    output_filename = f"{subject_name}_{file.split('.')[0]}_combined_content.txt"
                    output_path = os.path.join(output_directory, output_filename)
                    with open(output_path, 'w', encoding='utf-8') as outfile:
                        outfile.write(content)
                    print(f"Processed: {file} into {output_filename}")
            except Exception as e:
                print(f"Failed to process {file}: {e}")

    print(f"Total processed files: {processed_files}")
    print(f"Total skipped files: {skipped_files}")


# Call the function
process_directory_and_combine(notebooks_directory, output_directory)
# Out:
# Processed: CommonCommands.md into 01-Introduction-to-AI_CommonCommands_combined_content.txt
# Processed: terminal.md into 01-Introduction-to-AI_terminal_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: dishes_pseudocode.md into 01-Ins_Pseudocoding_dishes_pseudocode_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: laundry_pseudocode_solution.md into 02-Stu_Pseudocoding_Practice_laundry_pseudocode_solution_combined_content.txt
# Processed: laundry_pseudocode.md into 02-Stu_Pseudocoding_Practice_laundry_pseudocode_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: variables_solution.py into 03-Ins_Python_Intro_variables_solution_combined_content.txt
# Processed: variables.py into 03-Ins_Python_Intro_variables_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: hello_variable_world_solution.py into 04-Stu_Variables_hello_variable_world_solution_combined_content.txt
# Processed: hello_variable_world.py into 04-Stu_Variables_hello_variable_world_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: inputs_solution.py into 05-Ins_Prompts_inputs_solution_combined_content.txt
# Processed: inputs.py into 05-Ins_Prompts_inputs_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: input_order_solution.py into 06-Stu_Input_Order_input_order_solution_combined_content.txt
# Processed: input_order.py into 06-Stu_Input_Order_input_order_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: calculation_operators_solution.py into 07-Ins_Calculation_Operators_calculation_operators_solution_combined_content.txt
# Processed: calculation_operators.py into 07-Ins_Calculation_Operators_calculation_operators_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: vacation_calculator_solution.py into 08-Stu_Basic_Calculator_vacation_calculator_solution_combined_content.txt
# Processed: vacation_calculator.py into 08-Stu_Basic_Calculator_vacation_calculator_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: complex_strings_solution.py into 09-Ins_Complex_Strings_complex_strings_solution_combined_content.txt
# Processed: complex_strings.py into 09-Ins_Complex_Strings_complex_strings_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: print_presentation_solution.py into 10-Stu_Print_Presentation_print_presentation_solution_combined_content.txt
# Processed: print_presentation.py into 10-Stu_Print_Presentation_print_presentation_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process lists_tuples_solution.ipynb: name 'nbformat' is not defined
# Processed: lists_tuples_solution.py into 01-Ins_Lists_Tuples_lists_tuples_solution_combined_content.txt
# Failed to process lists_tuples.ipynb: name 'nbformat' is not defined
# Processed: lists_tuples.py into 01-Ins_Lists_Tuples_lists_tuples_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process create_a_menu_solution.ipynb: name 'nbformat' is not defined
# Processed: create_a_menu_solution.py into 02-Stu_Create_a_Menu_create_a_menu_solution_combined_content.txt
# Failed to process create_a_menu.ipynb: name 'nbformat' is not defined
# Processed: create_a_menu.py into 02-Stu_Create_a_Menu_create_a_menu_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process conditionals_solution.ipynb: name 'nbformat' is not defined
# Processed: conditionals_solution.py into 03-Ins_Conditionals_conditionals_solution_combined_content.txt
# Failed to process conditionals.ipynb: name 'nbformat' is not defined
# Processed: conditionals.py into 03-Ins_Conditionals_conditionals_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process conditional_conundrum_solution.ipynb: name 'nbformat' is not defined
# Processed: conditional_conundrum_solution.py into 04-Stu_Conditional_Conundrum_conditional_conundrum_solution_combined_content.txt
# Failed to process conditional_conundrum.ipynb: name 'nbformat' is not defined
# Processed: conditional_conundrum.py into 04-Stu_Conditional_Conundrum_conditional_conundrum_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process complex_conditionals_solution.ipynb: name 'nbformat' is not defined
# Processed: complex_conditionals_solution.py into 05-Ins_Complex_Conditionals_complex_conditionals_solution_combined_content.txt
# Failed to process complex_conditionals.ipynb: name 'nbformat' is not defined
# Processed: complex_conditionals.py into 05-Ins_Complex_Conditionals_complex_conditionals_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process smooth_operator_solution.ipynb: name 'nbformat' is not defined
# Processed: smooth_operator_solution.py into 06-Stu_Smooth_Operator_smooth_operator_solution_combined_content.txt
# Failed to process smooth_operator.ipynb: name 'nbformat' is not defined
# Processed: smooth_operator.py into 06-Stu_Smooth_Operator_smooth_operator_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process loops_solution.ipynb: name 'nbformat' is not defined
# Processed: loops_solution.py into 07-Ins_Loops_loops_solution_combined_content.txt
# Failed to process loops.ipynb: name 'nbformat' is not defined
# Processed: loops.py into 07-Ins_Loops_loops_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process travel_loops_solution.ipynb: name 'nbformat' is not defined
# Processed: travel_loops_solution.py into 08-Stu_Travel_Loops_travel_loops_solution_combined_content.txt
# Failed to process travel_loops.ipynb: name 'nbformat' is not defined
# Processed: travel_loops.py into 08-Stu_Travel_Loops_travel_loops_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process nested_decisions_solution.ipynb: name 'nbformat' is not defined
# Processed: nested_decisions_solution.py into 09-Ins_Nested_Decisions_nested_decisions_solution_combined_content.txt
# Failed to process nested_decisions.ipynb: name 'nbformat' is not defined
# Processed: nested_decisions.py into 09-Ins_Nested_Decisions_nested_decisions_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process loop_de_loop_solution.ipynb: name 'nbformat' is not defined
# Processed: loop_de_loop_solution.py into 10-Stu_Loop_De_Loop_loop_de_loop_solution_combined_content.txt
# Failed to process loop_de_loop.ipynb: name 'nbformat' is not defined
# Processed: loop_de_loop.py into 10-Stu_Loop_De_Loop_loop_de_loop_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process rock_paper_scissors_solution.ipynb: name 'nbformat' is not defined
# Processed: rock_paper_scissors_solution.py into 01-Evr_Rock_Paper_Scissors_rock_paper_scissors_solution_combined_content.txt
# Failed to process rock_paper_scissors.ipynb: name 'nbformat' is not defined
# Processed: rock_paper_scissors.py into 01-Evr_Rock_Paper_Scissors_rock_paper_scissors_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process match_case_solution.ipynb: name 'nbformat' is not defined
# Processed: match_case_solution.py into 02-Ins_Match_Case_match_case_solution_combined_content.txt
# Failed to process match_case.ipynb: name 'nbformat' is not defined
# Processed: match_case.py into 02-Ins_Match_Case_match_case_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process rps_match_case_solution.ipynb: name 'nbformat' is not defined
# Processed: rps_match_case_solution.py into 03-Stu_Refactor_Rock_Paper_Scissors_rps_match_case_solution_combined_content.txt
# Failed to process rps_match_case.ipynb: name 'nbformat' is not defined
# Processed: rps_match_case.py into 03-Stu_Refactor_Rock_Paper_Scissors_rps_match_case_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process dictionaries_solution.ipynb: name 'nbformat' is not defined
# Processed: dictionaries_solution.py into 04-Ins_Dictionaries_dictionaries_solution_combined_content.txt
# Failed to process dictionary_methods_solution.ipynb: name 'nbformat' is not defined
# Processed: dictionary_methods_solution.py into 04-Ins_Dictionaries_dictionary_methods_solution_combined_content.txt
# Failed to process dictionaries.ipynb: name 'nbformat' is not defined
# Processed: dictionaries.py into 04-Ins_Dictionaries_dictionaries_combined_content.txt
# Failed to process dictionary_methods.ipynb: name 'nbformat' is not defined
# Processed: dictionary_methods.py into 04-Ins_Dictionaries_dictionary_methods_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process hobby_dictionary_solution.ipynb: name 'nbformat' is not defined
# Processed: hobby_dictionary_solution.py into 05-Stu_Dictionaries_hobby_dictionary_solution_combined_content.txt
# Failed to process hobby_dictionary.ipynb: name 'nbformat' is not defined
# Processed: hobby_dictionary.py into 05-Stu_Dictionaries_hobby_dictionary_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process nested_data_solution.ipynb: name 'nbformat' is not defined
# Processed: nested_data_solution.py into 06-Ins_Nested_Data_Structures_nested_data_solution_combined_content.txt
# Failed to process nested_data.ipynb: name 'nbformat' is not defined
# Processed: nested_data.py into 06-Ins_Nested_Data_Structures_nested_data_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process explore_the_nest_solution.ipynb: name 'nbformat' is not defined
# Processed: explore_the_nest_solution.py into 07-Stu_Exploring_the_Nest_explore_the_nest_solution_combined_content.txt
# Failed to process explore_the_nest.ipynb: name 'nbformat' is not defined
# Processed: explore_the_nest.py into 07-Stu_Exploring_the_Nest_explore_the_nest_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process nested_dictionaries_solution.ipynb: name 'nbformat' is not defined
# Processed: nested_dictionaries_solution.py into 08-Ins_Nested_Dictionaries_nested_dictionaries_solution_combined_content.txt
# Failed to process nested_dictionaries.ipynb: name 'nbformat' is not defined
# Processed: nested_dictionaries.py into 08-Ins_Nested_Dictionaries_nested_dictionaries_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process print_a_menu_solution.ipynb: name 'nbformat' is not defined
# Processed: print_a_menu_solution.py into 09-Stu_Printing_a_Menu_print_a_menu_solution_combined_content.txt
# Failed to process print_a_menu.ipynb: name 'nbformat' is not defined
# Processed: print_a_menu.py into 09-Stu_Printing_a_Menu_print_a_menu_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process comprehensions_solution.ipynb: name 'nbformat' is not defined
# Processed: comprehensions_solution.py into 10-Ins_List_Comprehension_comprehensions_solution_combined_content.txt
# Failed to process comprehensions.ipynb: name 'nbformat' is not defined
# Processed: comprehensions.py into 10-Ins_List_Comprehension_comprehensions_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process guest_list_solution.ipynb: name 'nbformat' is not defined
# Processed: guest_list_solution.py into 11-Stu_Guest_List_guest_list_solution_combined_content.txt
# Failed to process guest_list.ipynb: name 'nbformat' is not defined
# Processed: guest_list.py into 11-Stu_Guest_List_guest_list_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process basic_functions_solution.ipynb: name 'nbformat' is not defined
# Processed: basic_functions_solution.py into 01-Ins_Functions_basic_functions_solution_combined_content.txt
# Failed to process basic_functions.ipynb: name 'nbformat' is not defined
# Processed: basic_functions.py into 01-Ins_Functions_basic_functions_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process a_definitive_buy_solution.ipynb: name 'nbformat' is not defined
# Processed: a_definitive_buy_solution.py into 02-Stu_Definitive_Buy_a_definitive_buy_solution_combined_content.txt
# Failed to process a_definitive_buy.ipynb: name 'nbformat' is not defined
# Processed: a_definitive_buy.py into 02-Stu_Definitive_Buy_a_definitive_buy_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process passing_arguments_solution.ipynb: name 'nbformat' is not defined
# Processed: passing_arguments_solution.py into 03-Ins_Variables_Arguments_passing_arguments_solution_combined_content.txt
# Failed to process variables_solution.ipynb: name 'nbformat' is not defined
# Processed: variables_solution.py into 03-Ins_Variables_Arguments_variables_solution_combined_content.txt
# Failed to process passing_arguments.ipynb: name 'nbformat' is not defined
# Processed: passing_arguments.py into 03-Ins_Variables_Arguments_passing_arguments_combined_content.txt
# Failed to process variables.ipynb: name 'nbformat' is not defined
# Processed: variables.py into 03-Ins_Variables_Arguments_variables_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process car_loan_calculator_solution.ipynb: name 'nbformat' is not defined
# Processed: car_loan_calculator_solution.py into 04-Stu_Car_Loan_Calculator_car_loan_calculator_solution_combined_content.txt
# Failed to process car_loan_calculator.ipynb: name 'nbformat' is not defined
# Processed: car_loan_calculator.py into 04-Stu_Car_Loan_Calculator_car_loan_calculator_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process returning_values_solution.ipynb: name 'nbformat' is not defined
# Processed: returning_values_solution.py into 05-Ins_Returning_Values_returning_values_solution_combined_content.txt
# Failed to process returning_values.ipynb: name 'nbformat' is not defined
# Processed: returning_values.py into 05-Ins_Returning_Values_returning_values_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Skipped: returned_goods_unsolved.ipynb
# Skipped: returned_goods_unsolved.py
# Failed to process returned_goods.ipynb: name 'nbformat' is not defined
# Processed: returned_goods.py into 06-Stu_Returned_Goods_returned_goods_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process map_lambda_filter_functions_solution.ipynb: name 'nbformat' is not defined
# Processed: map_lambda_filter_functions_solution.py into 07-Ins_Anonymous_Built-in_Functions_map_lambda_filter_functions_solution_combined_content.txt
# Failed to process map_lambda_filter_functions.ipynb: name 'nbformat' is not defined
# Processed: map_lambda_filter_functions.py into 07-Ins_Anonymous_Built-in_Functions_map_lambda_filter_functions_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process anonymous_functions_solution.ipynb: name 'nbformat' is not defined
# Processed: anonymous_functions_solution.py into 08-Stu_Map_Lambda_Filter_Functions_anonymous_functions_solution_combined_content.txt
# Failed to process anonymous_functions.ipynb: name 'nbformat' is not defined
# Processed: anonymous_functions.py into 08-Stu_Map_Lambda_Filter_Functions_anonymous_functions_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process documenting_code_solution.ipynb: name 'nbformat' is not defined
# Processed: documenting_code_solution.py into 09-Ins_Documenting_Code_documenting_code_solution_combined_content.txt
# Failed to process documenting_code.ipynb: name 'nbformat' is not defined
# Processed: documenting_code.py into 09-Ins_Documenting_Code_documenting_code_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process pizza_order_solution.ipynb: name 'nbformat' is not defined
# Processed: pizza_order_solution.py into 10-Stu_Pizza_Order_Documentation_pizza_order_solution_combined_content.txt
# Failed to process pizza_order.ipynb: name 'nbformat' is not defined
# Processed: pizza_order.py into 10-Stu_Pizza_Order_Documentation_pizza_order_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process import_modules_functions_methods_solution.ipynb: name 'nbformat' is not defined
# Processed: import_modules_functions_methods_solution.py into 01-Ins_Importing_Modules_Functions_Methods_import_modules_functions_methods_solution_combined_content.txt
# Failed to process import_modules_functions_methods.ipynb: name 'nbformat' is not defined
# Processed: import_modules_functions_methods.py into 01-Ins_Importing_Modules_Functions_Methods_import_modules_functions_methods_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process CarLoan.ipynb: name 'nbformat' is not defined
# Processed: CarLoan.py into 02-Stu_Importing_Car_Loan_Function_CarLoan_combined_content.txt
# Failed to process import_car_loan_function_solution.ipynb: name 'nbformat' is not defined
# Processed: import_car_loan_function_solution.py into 02-Stu_Importing_Car_Loan_Function_import_car_loan_function_solution_combined_content.txt
# Failed to process CarLoan.ipynb: name 'nbformat' is not defined
# Processed: CarLoan.py into 02-Stu_Importing_Car_Loan_Function_CarLoan_combined_content.txt
# Failed to process import_car_loan_function.ipynb: name 'nbformat' is not defined
# Processed: import_car_loan_function.py into 02-Stu_Importing_Car_Loan_Function_import_car_loan_function_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process refactoring_code_solution.ipynb: name 'nbformat' is not defined
# Processed: refactoring_code_solution.py into 03-Ins_Refactoring_Code_refactoring_code_solution_combined_content.txt
# Failed to process refactoring_code.ipynb: name 'nbformat' is not defined
# Processed: refactoring_code.py into 03-Ins_Refactoring_Code_refactoring_code_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process travel_loops.ipynb: name 'nbformat' is not defined
# Processed: travel_loops.py into 04-Evr_Recfactoring_Travel_Loops_travel_loops_combined_content.txt
# Failed to process travel_loops_refactoring_solution.ipynb: name 'nbformat' is not defined
# Processed: travel_loops_refactoring_solution.py into 04-Evr_Recfactoring_Travel_Loops_travel_loops_refactoring_solution_combined_content.txt
# Failed to process travel_loops.ipynb: name 'nbformat' is not defined
# Processed: travel_loops.py into 04-Evr_Recfactoring_Travel_Loops_travel_loops_combined_content.txt
# Failed to process travel_loops_refactoring.ipynb: name 'nbformat' is not defined
# Processed: travel_loops_refactoring.py into 04-Evr_Recfactoring_Travel_Loops_travel_loops_refactoring_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: ATM_User_Stories_solution.md into 06-Grp_ATM_User_Stories_ATM_User_Stories_solution_combined_content.txt
# Processed: ATM_User_Stories.md into 06-Grp_ATM_User_Stories_ATM_User_Stories_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process atm_login_solution.ipynb: name 'nbformat' is not defined
# Processed: atm_login_solution.py into 07-Ins_ATM_Application_Logic_atm_login_solution_combined_content.txt
# Failed to process atm_login.ipynb: name 'nbformat' is not defined
# Processed: atm_login.py into 07-Ins_ATM_Application_Logic_atm_login_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process atm_application_code_solution.ipynb: name 'nbformat' is not defined
# Processed: atm_application_code_solution.py into 08_Stu_ATM_Application_Code_atm_application_code_solution_combined_content.txt
# Failed to process atm_application_code.ipynb: name 'nbformat' is not defined
# Processed: atm_application_code.py into 08_Stu_ATM_Application_Code_atm_application_code_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process atm_modular_design_solution.ipynb: name 'nbformat' is not defined
# Processed: atm_modular_design_solution.py into 09-Ins_Modular_ATM_Design_atm_modular_design_solution_combined_content.txt
# Failed to process modular_atm_solution.ipynb: name 'nbformat' is not defined
# Processed: modular_atm_solution.py into 09-Ins_Modular_ATM_Design_modular_atm_solution_combined_content.txt
# Failed to process utils.ipynb: name 'nbformat' is not defined
# Processed: utils.py into 09-Ins_Modular_ATM_Design_utils_combined_content.txt
# Failed to process make_deposit.ipynb: name 'nbformat' is not defined
# Processed: make_deposit.py into Solved_make_deposit_combined_content.txt
# Failed to process make_withdrawal.ipynb: name 'nbformat' is not defined
# Processed: make_withdrawal.py into Solved_make_withdrawal_combined_content.txt
# Failed to process atm_modular_design.ipynb: name 'nbformat' is not defined
# Processed: atm_modular_design.py into 09-Ins_Modular_ATM_Design_atm_modular_design_combined_content.txt
# Failed to process utils.ipynb: name 'nbformat' is not defined
# Processed: utils.py into 09-Ins_Modular_ATM_Design_utils_combined_content.txt
# Failed to process make_deposit.ipynb: name 'nbformat' is not defined
# Processed: make_deposit.py into Unsolved_make_deposit_combined_content.txt
# Failed to process make_withdrawal.ipynb: name 'nbformat' is not defined
# Processed: make_withdrawal.py into Unsolved_make_withdrawal_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process modular_atm_solution.ipynb: name 'nbformat' is not defined
# Processed: modular_atm_solution.py into Solved_modular_atm_solution_combined_content.txt
# Failed to process utils.ipynb: name 'nbformat' is not defined
# Processed: utils.py into Solved_utils_combined_content.txt
# Failed to process make_deposit.ipynb: name 'nbformat' is not defined
# Processed: make_deposit.py into atm_make_deposit_combined_content.txt
# Failed to process make_withdrawal.ipynb: name 'nbformat' is not defined
# Processed: make_withdrawal.py into atm_make_withdrawal_combined_content.txt
# Failed to process modular_atm.ipynb: name 'nbformat' is not defined
# Processed: modular_atm.py into Unsolved_modular_atm_combined_content.txt
# Processed: utils.py into Unsolved_utils_combined_content.txt
# Processed: make_deposit.py into atm_make_deposit_combined_content.txt
# Processed: make_withdrawal.py into atm_make_withdrawal_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: oop_basics_solution.py into 01-Ins_OOP_Basics_oop_basics_solution_combined_content.txt
# Processed: oop_example.py into 01-Ins_OOP_Basics_oop_example_combined_content.txt
# Processed: oop_basics.py into 01-Ins_OOP_Basics_oop_basics_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: car_class_solution.py into 02-Stu_Modify_Car_Class_car_class_solution_combined_content.txt
# Processed: car_class.py into 02-Stu_Modify_Car_Class_car_class_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: adding_methods_solution.py into 03-Ins_Adding_Methods_adding_methods_solution_combined_content.txt
# Processed: adding_methods.py into 03-Ins_Adding_Methods_adding_methods_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: adding_car_class_methods_solution.py into 04-Stu_Add_Methods_Car_Class_adding_car_class_methods_solution_combined_content.txt
# Processed: adding_car_class_methods.py into 04-Stu_Add_Methods_Car_Class_adding_car_class_methods_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: Car.py into 05-Ins-Creating_Modules_Car_combined_content.txt
# Processed: car_data_solution.py into 05-Ins-Creating_Modules_car_data_solution_combined_content.txt
# Processed: Car.py into 05-Ins-Creating_Modules_Car_combined_content.txt
# Processed: car_data.py into 05-Ins-Creating_Modules_car_data_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: bankaccount.py into 06-Stu_Bank_Account_Class_bankaccount_combined_content.txt
# Processed: banking_solution.py into 06-Stu_Bank_Account_Class_banking_solution_combined_content.txt
# Processed: BankAccount.py into 06-Stu_Bank_Account_Class_BankAccount_combined_content.txt
# Processed: banking.py into 06-Stu_Bank_Account_Class_banking_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: CarData.py into 07-Ins_Inheritance_CarData_combined_content.txt
# Processed: car_extras_solution.py into 07-Ins_Inheritance_car_extras_solution_combined_content.txt
# Processed: CarData.py into 07-Ins_Inheritance_CarData_combined_content.txt
# Processed: car_extras.py into 07-Ins_Inheritance_car_extras_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: Accounts.py into 08-Stu_Account_Inheritance_Accounts_combined_content.txt
# Processed: account_inheritance_solution.py into 08-Stu_Account_Inheritance_account_inheritance_solution_combined_content.txt
# Processed: Accounts.py into 08-Stu_Account_Inheritance_Accounts_combined_content.txt
# Processed: account_inheritance.py into 08-Stu_Account_Inheritance_account_inheritance_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process creating_data_frames_solution.ipynb: name 'nbformat' is not defined
# Failed to process creating_data_frames.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process DataFrame_shop_solution.ipynb: name 'nbformat' is not defined
# Failed to process DataFrame_shop.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process pandas_reading_files_solution.ipynb: name 'nbformat' is not defined
# Failed to process pandas_reading_files.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process column_manipulation_solution.ipynb: name 'nbformat' is not defined
# Failed to process column_manipulation.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process columns_solution.ipynb: name 'nbformat' is not defined
# Failed to process columns.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process indexing_solution.ipynb: name 'nbformat' is not defined
# Failed to process indexing.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process good_movies_solution.ipynb: name 'nbformat' is not defined
# Failed to process good_movies.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process comic_books_solution.ipynb: name 'nbformat' is not defined
# Failed to process comic_books.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process dataframe_review_solution.ipynb: name 'nbformat' is not defined
# Failed to process dataframe_review_solution.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process sorting_data_solution.ipynb: name 'nbformat' is not defined
# Failed to process sorting_data.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process exploring_data_solution.ipynb: name 'nbformat' is not defined
# Failed to process exploring_data.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process search_for_the_worst_solution.ipynb: name 'nbformat' is not defined
# Failed to process search_for_the_worst.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process summary_stats_solution.ipynb: name 'nbformat' is not defined
# Failed to process summary_stats.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process outliers_solution.ipynb: name 'nbformat' is not defined
# Failed to process outliers.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process summary_stats_solved.ipynb: name 'nbformat' is not defined
# Failed to process summary_stats_unsovled.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Pandas_recap_solution.ipynb: name 'nbformat' is not defined
# Failed to process Pandas_recap.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process data_functions_solution.ipynb: name 'nbformat' is not defined
# Failed to process data_functions.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process training_grounds_solution.ipynb: name 'nbformat' is not defined
# Failed to process training_grounds.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process apply_solution.ipynb: name 'nbformat' is not defined
# Failed to process apply.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process apply_taxes_solution.ipynb: name 'nbformat' is not defined
# Failed to process apply_taxes.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process spring_cleaning.ipynb: name 'nbformat' is not defined
# Failed to process spring_cleaning.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process answering_abstract_questions_solution.ipynb: name 'nbformat' is not defined
# Failed to process answering_abstract_questions_blank.ipynb: name 'nbformat' is not defined
# Failed to process answering_abstract_questions_starter.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process concatenate_stocks_solution.ipynb: name 'nbformat' is not defined
# Failed to process concatenate_stocks.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process concat_country_products_solution.ipynb: name 'nbformat' is not defined
# Failed to process concat_country_products.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process joining_data_solution.ipynb: name 'nbformat' is not defined
# Failed to process joining_data.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process joining_alternative_energy_solution.ipynb: name 'nbformat' is not defined
# Failed to process joining_alternative_energy.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process merging_solution.ipynb: name 'nbformat' is not defined
# Failed to process merging.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process census_merging_solution.ipynb: name 'nbformat' is not defined
# Failed to process census_merging.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process merging_duplicate_columns_solution.ipynb: name 'nbformat' is not defined
# Failed to process merging_duplicate_columns.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process merge_wheat_production_solution.ipynb: name 'nbformat' is not defined
# Failed to process merge_wheat_production.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process groupby_solution.ipynb: name 'nbformat' is not defined
# Failed to process groupby.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process training_groupby_solution.ipynb: name 'nbformat' is not defined
# Failed to process training_groupby.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process groupby_multiple_columns_aggregation_solution.ipynb: name 'nbformat' is not defined
# Failed to process groupby_multiple_columns_aggregation.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process groupby_multiple_column_aggregation_delayed_flights_solution.ipynb: name 'nbformat' is not defined
# Failed to process groupby_multiple_column_aggregation_delayed_flights.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process customizing_aggregations_solution.ipynb: name 'nbformat' is not defined
# Failed to process customizing_aggregations.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process delayed_flights_custom_aggregations_solution.ipynb: name 'nbformat' is not defined
# Failed to process delayed_flights_custom_aggregations.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process binning_and_groupby_solution.ipynb: name 'nbformat' is not defined
# Failed to process binning_and_groupby.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process binning_movies_solution.ipynb: name 'nbformat' is not defined
# Failed to process binning_movies.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process pivot_book_sales_solution.ipynb: name 'nbformat' is not defined
# Failed to process pivot_book_sales.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process pivoting_exam_scores_solution.ipynb: name 'nbformat' is not defined
# Failed to process pivoting_exam_scores.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process multi_indexing_pivoting_solution.ipynb: name 'nbformat' is not defined
# Failed to process multi_indexing_pivoting.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process multi-indexing_pivoting_car_sales_solution.ipynb: name 'nbformat' is not defined
# Failed to process multi-indexing_pivoting_car_sales.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process custom_agg_multi_indexing_pivot_solution.ipynb: name 'nbformat' is not defined
# Failed to process custom_agg_multi_indexing_pivot.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process custom_agg_multiIndex_pivot_delayed_flights_solution.ipynb: name 'nbformat' is not defined
# Failed to process custom_agg_multiIndex_pivot_delayed_flights.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process resample_melt_solution.ipynb: name 'nbformat' is not defined
# Failed to process resample_melt.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process resampling_melting_DataFrames_solution.ipynb: name 'nbformat' is not defined
# Failed to process resampling_melting_DataFrames.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process extract_html_table_data_solution.ipynb: name 'nbformat' is not defined
# Failed to process extract_html_table_data.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process world_cup_stats_solution.ipynb: name 'nbformat' is not defined
# Failed to process world_cup_stats.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process python_requests_solution.ipynb: name 'nbformat' is not defined
# Failed to process python_requests.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process python_requests_solution.ipynb: name 'nbformat' is not defined
# Failed to process python_requests.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process url_parameters_solution.ipynb: name 'nbformat' is not defined
# Failed to process url_parameters.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process url_parameters_solution.ipynb: name 'nbformat' is not defined
# Failed to process url_parameters.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process iterative_requests_json_to_pandas_solution.ipynb: name 'nbformat' is not defined
# Failed to process iterative_requests_json_to_pandas.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process TV_ratings_solution.ipynb: name 'nbformat' is not defined
# Failed to process TV_ratings.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process number_facts_solution.ipynb: name 'nbformat' is not defined
# Failed to process number_facts.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process env_variables_solution.ipynb: name 'nbformat' is not defined
# Failed to process env_variables.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process env_variables_tmdb_requests_solution.ipynb: name 'nbformat' is not defined
# Failed to process env_variables_tmdb_requests.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process nyt_api_solution.ipynb: name 'nbformat' is not defined
# Failed to process nyt_api.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process retrieve_articles_solution.ipynb: name 'nbformat' is not defined
# Failed to process retrieve_articles.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process open_weather_dataframe_solution.ipynb: name 'nbformat' is not defined
# Failed to process open_weather_dataframe.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process weather_info_solution.ipynb: name 'nbformat' is not defined
# Failed to process weather_info.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process exception_example.ipynb: name 'nbformat' is not defined
# Failed to process exception_handling_solution.ipynb: name 'nbformat' is not defined
# Failed to process exception_handling.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process making_exceptions_solution.ipynb: name 'nbformat' is not defined
# Failed to process making_exceptions.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process api_exceptions_solution.ipynb: name 'nbformat' is not defined
# Failed to process api_exceptions.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process nyt_movie_review_articles_solution.ipynb: name 'nbformat' is not defined
# Failed to process nyt_movie_review_articles.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process census_demo_solution.ipynb: name 'nbformat' is not defined
# Failed to process census_demo.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process census_solution.ipynb: name 'nbformat' is not defined
# Failed to process census.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process open_library_example_solution.ipynb: name 'nbformat' is not defined
# Processed: open_library_script_solution.py into 04-Grp_API_Mini_Project_open_library_script_solution_combined_content.txt
# Failed to process api_exploration.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process ExploreRelationships_solution.ipynb: name 'nbformat' is not defined
# Failed to process ExploreRelationships.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process IntroPyPlotLinePlots_solution.ipynb: name 'nbformat' is not defined
# Failed to process IntroPyPlotLinePlots.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process MakeLinePlot_solution.ipynb: name 'nbformat' is not defined
# Failed to process MakeLinePlot.ipynb: name 'nbformat' is not defined
# Processed: Readme.md into Activities_Readme_combined_content.txt
# Failed to process ConfiguringLinePlots_solution.ipynb: name 'nbformat' is not defined
# Failed to process ConfiguringLinePlots_solution.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process LegendaryTemp_solution.ipynb: name 'nbformat' is not defined
# Failed to process LegendaryTemp.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process BarCharts_solution.ipynb: name 'nbformat' is not defined
# Failed to process BarCharts.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process CarsBarChart_solution.ipynb: name 'nbformat' is not defined
# Failed to process CarsBarChart.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process ScatterPlots_solution.ipynb: name 'nbformat' is not defined
# Failed to process ScatterPlots.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process ScatterPy_solution.ipynb: name 'nbformat' is not defined
# Failed to process ScatterPy.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process PyPlotWarmup_solution.ipynb: name 'nbformat' is not defined
# Failed to process PyPlotWarmup.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process PlottingPandasData_solution.ipynb: name 'nbformat' is not defined
# Failed to process PlottingPandasData.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process UnionSettlements_solution.ipynb: name 'nbformat' is not defined
# Failed to process settlements.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process PlottingGroups_solution.ipynb: name 'nbformat' is not defined
# Failed to process PlottingGroups.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process LibraryUsage-Groupby_solution.ipynb: name 'nbformat' is not defined
# Failed to process LibraryUsage-Groupby.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process MilesPerGallon-ScatterPlot_solution.ipynb: name 'nbformat' is not defined
# Failed to process MilesPerGallon-ScatterPlot.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process PlotMultipleLines_solution.ipynb: name 'nbformat' is not defined
# Failed to process PlotMultipleLines.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Travel-Part1_solution.ipynb: name 'nbformat' is not defined
# Failed to process Travel-Part1.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Travel-Part2_solution.ipynb: name 'nbformat' is not defined
# Failed to process Travel-Part2.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Travel-Part3_solution.ipynb: name 'nbformat' is not defined
# Failed to process Travel-Part3.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Stats-Review_solution.ipynb: name 'nbformat' is not defined
# Failed to process Stats-Review.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Box-Plots_solution.ipynb: name 'nbformat' is not defined
# Failed to process Box-Plots.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Temperature-Outliers_solution.ipynb: name 'nbformat' is not defined
# Failed to process Temperature-Outliers.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Sample-Population-SEM_solution.ipynb: name 'nbformat' is not defined
# Failed to process Sample-Population-SEM.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process SEM-Error-Bars_solution.ipynb: name 'nbformat' is not defined
# Failed to process SEM-Error-Bars.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Correlation-Conundrum_solution.ipynb: name 'nbformat' is not defined
# Failed to process Correlation-Conundrum.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Correlation-Conquerors_solution.ipynb: name 'nbformat' is not defined
# Failed to process Correlation-Conquerors.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Fits-and-Regression_solution.ipynb: name 'nbformat' is not defined
# Failed to process Fits-and-Regression.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Fits-and-Regression_solution.ipynb: name 'nbformat' is not defined
# ...
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process preprocessing_fungi_solution.ipynb: name 'nbformat' is not defined
# Failed to process preprocessing_fungi.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process image_labels_solution.ipynb: name 'nbformat' is not defined
# Failed to process image_labels.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process labeling_images_solution.ipynb: name 'nbformat' is not defined
# Failed to process labeling_images.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process build_a_basic_cnn_solution.ipynb: name 'nbformat' is not defined
# Failed to process build_a_basic_cnn.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process build_a_cnn_solution.ipynb: name 'nbformat' is not defined
# Failed to process build_a_cnn.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process augmenting_data_solution.ipynb: name 'nbformat' is not defined
# Failed to process augmenting_data.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process augmenting_one_image_solution.ipynb: name 'nbformat' is not defined
# Failed to process augmenting_one_image.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process augmenting_fungi_solution.ipynb: name 'nbformat' is not defined
# Failed to process augmenting_fungi.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process building_cnn_from_scratch_solution.ipynb: name 'nbformat' is not defined
# Failed to process building_cnn_from_scratch.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process branching_solution.ipynb: name 'nbformat' is not defined
# Failed to process branching.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process preparing_faces_for_branching_solution.ipynb: name 'nbformat' is not defined
# Failed to process preparing_faces_for_branching.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process branching_faces_solution.ipynb: name 'nbformat' is not defined
# Failed to process branching_faces.ipynb: name 'nbformat' is not defined
# Processed: LessonPlan.md into 20-NLP_LessonPlan_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process tokenization_solution.ipynb: name 'nbformat' is not defined
# Failed to process tokenization.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process tokenizing_reuters_solution.ipynb: name 'nbformat' is not defined
# Failed to process tokenizing_reuters.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process stopwords_solution.ipynb: name 'nbformat' is not defined
# Failed to process stopwords.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process crude_oil_stopwords_solution.ipynb: name 'nbformat' is not defined
# Failed to process crude_oil_stopwords.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process lemmatization_solution.ipynb: name 'nbformat' is not defined
# Failed to process stemming_solution.ipynb: name 'nbformat' is not defined
# Failed to process lemmatization.ipynb: name 'nbformat' is not defined
# Failed to process stemming.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process stemming_lemmatizing_moby_dick_solution.ipynb: name 'nbformat' is not defined
# Failed to process stemming_lemmatizing_moby_dick.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process ngram_count_solution.ipynb: name 'nbformat' is not defined
# Failed to process ngram_count.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process word_bigram_corpus_counter_solution.ipynb: name 'nbformat' is not defined
# Failed to process word_bigram_corpus_counter.ipynb: name 'nbformat' is not defined
# Processed: LessonPlan.md into 20-NLP_LessonPlan_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process terms_relevance_solution.ipynb: name 'nbformat' is not defined
# Failed to process terms_relevance.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process money_words_solution.ipynb: name 'nbformat' is not defined
# Failed to process money_words.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process sms_text_classification_solution copy.ipynb: name 'nbformat' is not defined
# Failed to process sms_text_classification_solution.ipynb: name 'nbformat' is not defined
# Failed to process sms_text_classification.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process movie_review_classification_solution.ipynb: name 'nbformat' is not defined
# Failed to process movie_review_classification.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process pos_tagging_solution.ipynb: name 'nbformat' is not defined
# Failed to process pos_tagging.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process describing_america_solution.ipynb: name 'nbformat' is not defined
# Failed to process describing_america.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process ner_coffee_solution.ipynb: name 'nbformat' is not defined
# Failed to process ner_coffee.ipynb: name 'nbformat' is not defined
# Processed: LessonPlan.md into 20-NLP_LessonPlan_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Latent_Dirichlet_Allocation_solution.ipynb: name 'nbformat' is not defined
# Failed to process Latent_Dirichlet_Allocation.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process BBC_news_LDA_solution.ipynb: name 'nbformat' is not defined
# Failed to process BBC_news_LDA.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process Non-Negative-Matrix-Factorization_solution.ipynb: name 'nbformat' is not defined
# Failed to process Non-Negative-Matrix-Factorization.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process BBC_news_NMF_solution.ipynb: name 'nbformat' is not defined
# Failed to process BBC_news_NMF.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process LSTM_Text_Generation_solution.ipynb: name 'nbformat' is not defined
# Failed to process LSTM_Text_Generation.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process The_Case_of_the_Vanishing_Gradient_solution.ipynb: name 'nbformat' is not defined
# Failed to process The_Case_of_the_Vanishing_Gradient.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process BoW_model_solution.ipynb: name 'nbformat' is not defined
# Failed to process BoW_model.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process subword_tokenization_solution.ipynb: name 'nbformat' is not defined
# Failed to process subword_tokenization.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process tokens_to_indices_review_solution.ipynb: name 'nbformat' is not defined
# Failed to process tokens_to_indices_review.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process sentence_tokenizer_solution.ipynb: name 'nbformat' is not defined
# Failed to process similarity_measures_solution.ipynb: name 'nbformat' is not defined
# Failed to process sentence_tokenizer.ipynb: name 'nbformat' is not defined
# Failed to process similarity_measures.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process similarity_search_engine_solution.ipynb: name 'nbformat' is not defined
# Failed to process similarity_search_engine.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process sms_ham_spam_similarity_solution.ipynb: name 'nbformat' is not defined
# Failed to process sms_ham_spam_similarity.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process text_translation_pipeline_solution.ipynb: name 'nbformat' is not defined
# Failed to process text_translation_solution.ipynb: name 'nbformat' is not defined
# Failed to process text_translation.ipynb: name 'nbformat' is not defined
# Failed to process text_translation_pipeline.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process headlines_translation_solution.ipynb: name 'nbformat' is not defined
# Failed to process headlines_translation.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process text_generation_solution.ipynb: name 'nbformat' is not defined
# Failed to process text_generation.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process testing_text_generators_solution.ipynb: name 'nbformat' is not defined
# Failed to process testing_text_generators.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process question_answering_solution.ipynb: name 'nbformat' is not defined
# Failed to process question_answering.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process question_answering_testing_solution.ipynb: name 'nbformat' is not defined
# Failed to process question_answering.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process text_summarization_solution.ipynb: name 'nbformat' is not defined
# Failed to process text_summarization.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process student_text_summarization_solution.ipynb: name 'nbformat' is not defined
# Failed to process student_text_summarization.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process gradio_demonstration_solution.ipynb: name 'nbformat' is not defined
# Failed to process gradio_demonstration.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process gradio_pizza_order_solution.ipynb: name 'nbformat' is not defined
# Failed to process gradio_pizza_order.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process gradio_text_summarization_solution.ipynb: name 'nbformat' is not defined
# Failed to process gradio_text_summarization.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process student_gradio_text_summarization_solution.ipynb: name 'nbformat' is not defined
# Failed to process student_gradio_text_summarization.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process gradio_other_components_solution.ipynb: name 'nbformat' is not defined
# Failed to process gradio_other_components.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process gradio_question_answer_textbox_solution.ipynb: name 'nbformat' is not defined
# Processed: app.py into Solved_app_combined_content.txt
# Failed to process gradio_question_answer_textbox.ipynb: name 'nbformat' is not defined
# Failed to process question_answering_solution.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process intro_langchain_solution.ipynb: name 'nbformat' is not defined
# Failed to process intro_langchain.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process langchain_practice_solution.ipynb: name 'nbformat' is not defined
# Failed to process langchain_practice.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process external_sources_solution.ipynb: name 'nbformat' is not defined
# Failed to process external_sources.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process api_chat_solution.ipynb: name 'nbformat' is not defined
# Failed to process api_chat.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process conversational_memory_solution.ipynb: name 'nbformat' is not defined
# Failed to process conversational_memory.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process event_planner_solution.ipynb: name 'nbformat' is not defined
# Failed to process event_planner.ipynb: name 'nbformat' is not defined
# Processed: chatdoc.py into 22-Emerging-AI-Topics_chatdoc_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process prompt_templates_solution.ipynb: name 'nbformat' is not defined
# Failed to process prompt_templates.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process quote_generator_solution.ipynb: name 'nbformat' is not defined
# Failed to process quote_generator.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process output_parsers_solution.ipynb: name 'nbformat' is not defined
# Failed to process output_parsers.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process recipe_info_solution.ipynb: name 'nbformat' is not defined
# Failed to process recipe_info.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process agents_solution.ipynb: name 'nbformat' is not defined
# Failed to process agents.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Failed to process activity_planner_solution.ipynb: name 'nbformat' is not defined
# Failed to process activity_planner.ipynb: name 'nbformat' is not defined
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Processed: README.md into Activities_README_combined_content.txt
# Total processed files: 534
# Total skipped files: 2

# %%
def read_all_files(directory):
    file_data = {}
    for filename in os.listdir(directory):
        if filename.endswith(".txt"):
            subject_name = filename.split('_')[0]  # Assuming the subject is the first part of the filename
            file_path = os.path.join(directory, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                file_data.setdefault(subject_name, []).append(file.read())
    return file_data

def read_pdf_files(pdf_directory):
    pdf_data = {}
    for filename in os.listdir(pdf_directory):
        if filename.endswith(".pdf"):
            subject_name = filename.split('_')[0]
            pdf_path = os.path.join(pdf_directory, filename)
            try:
                with fitz.open(pdf_path) as doc:
                    text_content = []
                    for page in doc:
                        text_content.append(page.get_text())
                    pdf_data.setdefault(subject_name, []).append("\n".join(text_content))
            except Exception as e:
                print(f"Failed to read {filename}: {e}")
    return pdf_data

def read_transcript_files(transcripts_directory):
    transcript_data = {}
    for filename in os.listdir(transcripts_directory):
        if filename.endswith(".txt"):
            subject_name = filename.split('_')[0]  # Assuming the subject is the first part of the filename
            file_path = os.path.join(transcripts_directory, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                transcript_data.setdefault(subject_name, []).append(file.read())
    return transcript_data

# Paths to the directories
notebooks_directory = "Lesson-Plans"
pdf_slides_directory = "Slides"
transcripts_directory = "Transcripts"
output_directory = "Output"

# Read the processed markdown and code files
markdown_code_data = read_all_files(notebooks_directory)
print("Markdown/code files read successfully.")

# Read the PDF slides
pdf_slides_data = read_pdf_files(pdf_slides_directory)
print("PDF slides read successfully.")

# Read transcripts
transcripts_data = read_transcript_files(transcripts_directory)
print("Transcript files read successfully.")

# Combine the data by subject
combined_subject_data = {}
all_subjects = set(markdown_code_data) | set(pdf_slides_data) | set(transcripts_data)
for subject in all_subjects:
    combined_subject_data[subject] = []
    if subject in markdown_code_data:
        combined_subject_data[subject].extend(markdown_code_data[subject])
    if subject in pdf_slides_data:
        combined_subject_data[subject].extend(pdf_slides_data[subject])
    if subject in transcripts_data:
        combined_subject_data[subject].extend(transcripts_data[subject])

print("All subjects combined successfully.")
# Out:
# Markdown/code files read successfully.
# PDF slides read successfully.
# Transcript files read successfully.
# All subjects combined successfully.

# %%
def display_data_snippets(data, num_lines=5):
    for subject, contents in data.items():
        print(f"Subject: {subject}\n")
        for content in contents:
            # Split the content into lines and display the first few lines
            lines = content.split('\n')
            print('\n'.join(lines[:num_lines]))
            print("\n---\n")  # Separator between different contents
        print("\n==========\n")  # Separator between different subjects

# Call the function to display snippets from the markdown/code data
display_data_snippets(markdown_code_data)

# Call the function to display snippets from the PDF slides data
display_data_snippets(pdf_slides_data)
# Out:
# Subject: M1.2
#
# AI Boot Camp
# The Impact of
# Machine Learning
# Module 1 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M1.3
#
# AI Boot Camp
# Overview of Machine
# Learning Tools
# Module 1 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M11.1
#
# AI Bootcamp
# Module 11 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Introduction to
# Machine Learning
#
# ---
#
#
# ==========
#
# Subject: M11.2
#
# AI Bootcamp
# Module 11 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Unsupervised Learning
# in Practice
#
# ---
#
#
# ==========
#
# Subject: M11.3
#
# AI Bootcamp
# Module 11 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Principal Component
# Analysis (PCA)
#
# ---
#
#
# ==========
#
# Subject: M12.1
#
# AI Bootcamp
# Module 12 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Introduction to
# Supervised Learning
#
# ---
#
#
# ==========
#
# Subject: M12.2
#
# AI Bootcamp
# Module 12 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Advanced Regression
# Techniques
#
# ---
#
#
# ==========
#
# Subject: M13.1
#
# AI Bootcamp
# Module 13 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Linear Classiﬁcation
#
#
# ---
#
#
# ==========
#
# Subject: M13.2
#
# AI Bootcamp
# Module 13 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Nonlinear
# Classiﬁcation
#
# ---
#
#
# ==========
#
# Subject: M13.3
#
# AI Bootcamp
# Module 13 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Model Selection and
# Multiclass Classiﬁcation
#
# ---
#
#
# ==========
#
# Subject: M14.1
#
# AI Bootcamp
# Module 14 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Model Validation
# and Imbalanced Data
#
# ---
#
#
# ==========
#
# Subject: M14.2
#
# AI Bootcamp
# Module 14 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Advanced
# Preprocessing
#
# ---
#
#
# ==========
#
# Subject: M14.3
#
# AI Bootcamp
# Module 14 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Tuning Models
# and Sampling Data
#
# ---
#
#
# ==========
#
# Subject: M15.1
#
# AI Boot Camp
# Module 15 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# AI Ethics:
# An Introduction
#
# ---
#
#
# ==========
#
# Subject: M15.2
#
# AI Boot Camp
# Module 15 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Legal and Ethical
# Issues in AI
#
# ---
#
#
# ==========
#
# Subject: M15.3
#
# AI Boot Camp
# Module 15 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# AI Laws
# and Regulations
#
# ---
#
#
# ==========
#
# Subject: M18.1
#
# AI Bootcamp
# Neural Networks
# Module 18 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
#
# ---
#
#
# ==========
#
# Subject: M18.2
#
# AI Bootcamp
# Neural Networks
# for Classiﬁcation
# Module 18 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M18.3
#
# AI Bootcamp
# RBMs and
# Recommendation
# Engines
# Module 18 Day 3
#
# ---
#
#
# ==========
#
# Subject: M19.1
#
# AI Bootcamp
# Preprocessing
# Image Data
# Module 19 Day 1
# © 2024 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M19.2
#
# AI Bootcamp
# Image Classiﬁcation
# With Neural Networks
# Module 19 Day 2
# © 2024 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M19.3
#
# AI Bootcamp
# Multiclass Image
# Classiﬁcation With CNNs
# Module 19 Day 3
# © 2024 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M2.1
#
# AI Boot Camp
# Programming
# Basics
# Module 2 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M2.2
#
# AI Boot Camp
# Module 2 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Programming
# Decisions
#
# ---
#
#
# ==========
#
# Subject: M2.3
#
# AI Boot Camp
# Complex
# Programming
# Decisions
# Module 2 Day 3
#
# ---
#
#
# ==========
#
# Subject: M20.1
#
# AI Bootcamp
# Introduction to
# Natural Language
# Processing (NLP)
# Module 20 Day 1
#
# ---
#
#
# ==========
#
# Subject: M20.2
#
# AI Bootcamp
# Advanced NLP
# Techniques– Text
# Extraction
# and Classiﬁcation
#
# ---
#
#
# ==========
#
# Subject: M20.3
#
# AI Bootcamp
# Advanced NLP Techniques:
# Topic Modeling and RNN
# Module 20 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M21.1
#
# AI Bootcamp
# Tokenizers and Large
# Language Models
# Module 21 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M21.2
#
# AI Bootcamp
# Introduction to Hugging
# Face Transformers
# Module 21 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M21.3
#
# AI Bootcamp
# AI Applications
# with Gradio
# Module 21 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M22.1
#
# AI Bootcamp
# Emerging Topics in AI
# Module 22 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
#
# ---
#
#
# ==========
#
# Subject: M22.2
#
# AI Bootcamp
# Prompt Engineering,
# Output Parsers
# & Agents
# Module 22 Day 2
#
# ---
#
#
# ==========
#
# Subject: M22.3
#
# AI Bootcamp
# The Future of AI
# Module 22 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
#
# ---
#
#
# ==========
#
# Subject: M3.1
#
# AI Boot Camp
# Module 3 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Programming with
# Functions — Part 1
#
# ---
#
#
# ==========
#
# Subject: M3.2
#
# AI Boot Camp
# Programming with
# Functions — Part 2
# Module 3 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M3.3
#
# AI Boot Camp
# Module 3 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
# Python Classes
# and OOP
#
# ---
#
#
# ==========
#
# Subject: M4.2
#
# AI Boot Camp
# Exploring Data
# with Pandas
# Module 4 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M4.3
#
# AI Boot Camp
# Transforming
# Data with
# Pandas
# Module 4 Day 3
#
# ---
#
#
# ==========
#
# Subject: M5.1
#
# AI Bootcamp
# Combining DataFrames
# with Pandas
# Module 5 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M5.2
#
# AI Bootcamp
# Grouping, Aggregating,
# and Binning Data
# with Pandas
# Module 5 Day 2
#
# ---
#
#
# ==========
#
# Subject: M5.3
#
# AI Bootcamp
# Advanced Data Reshaping
# with Pandas
# Module 5 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M6.1
#
# AI Bootcamp
# Sourcing Data
# for AI Projects
# Module 6 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M6.2
#
# AI Bootcamp
# Accessing
# APIs Securely
# Module 6 Day 2
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M6.3
#
# AI Bootcamp
# SDKs and
# Mini In-Class Project
# Module 6 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M7.1
#
# AI Boot Camp
# Exploring Data
# through
# Visualizations
# Module 7 Day 1
#
# ---
#
#
# ==========
#
# Subject: M7.2
#
# AI Boot Camp
# Visualizing
# DataFrames
# Using Pandas
# Module 7 Day 2
#
# ---
#
#
# ==========
#
# Subject: M7.3
#
# AI Boot Camp
# Visualization
# and Statistics
# Module 7 Day 3
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M8.1
#
# AI Boot Camp
# Introduction to
# Time Series
# Module 8 Day 1
# © 2023 edX Boot Camps LLC. Conﬁdential and Proprietary. All Rights Reserved.
#
# ---
#
#
# ==========
#
# Subject: M8.2
#
# AI Boot Camp
# Introduction to
# Time Series
# Forecasting
# Module 8 Day 2
#
# ---
#
#
# ==========
#
# Subject: M8.3
#
# AI Boot Camp
# Time Series
# Forecasting
# with Prophet
# Module 8 Day 3
#
# ---
#
#
# ==========

# %%
# Display all subjects from markdown/code files
print("Subjects from markdown/code files:")
for subject in markdown_code_data.keys():
    print(subject)

# Display all subjects from PDF slides
print("\nSubjects from PDF slides:")
for subject in pdf_slides_data.keys():
    print(subject)

# Display all subjects from transcripts
print("\nSubjects from transcripts:")
for subject in transcripts_data.keys():
    print(subject)
# Out:
# Subjects from markdown/code files:
#
# Subjects from PDF slides:
# M1.2
# M1.3
# M11.1
# M11.2
# M11.3
# M12.1
# M12.2
# M13.1
# M13.2
# M13.3
# M14.1
# M14.2
# M14.3
# M15.1
# M15.2
# M15.3
# M18.1
# M18.2
# M18.3
# M19.1
# M19.2
# M19.3
# M2.1
# M2.2
# M2.3
# M20.1
# M20.2
# M20.3
# M21.1
# M21.2
# M21.3
# M22.1
# M22.2
# M22.3
# M3.1
# M3.2
# M3.3
# M4.2
# M4.3
# M5.1
# M5.2
# M5.3
# M6.1
# M6.2
# M6.3
# M7.1
# M7.2
# M7.3
# M8.1
# M8.2
# M8.3
#
# Subjects from transcripts:
# Data Ethics 1.txt
# Data Ethics 2 - Keith Ellis.txt
# Data Ethics 3.txt
# Deep Learning 1.txt
# Deep Learning 2.txt
# Deep Learning 3.txt
# Emerging Topics in AI 1.txt
# Emerging Topics in AI 2.txt
# Emerging Topics in AI 3.txt
# Exploring Data through Visualizations 1 (Section 2).txt
# Exploring Data through Visualizations 1.txt
# Exploring Data through Visualizations 2.txt
# Exploring Data through Visualizations 3.txt
# Extra Review 1.txt
# Extra Review Static Website.txt
# Introduction to AI 1.txt
# Introduction to AI 2.txt
# Introduction to AI 3.txt
# Machine Learning Optimization 1.txt
# Machine Learning Optimization 2.txt
# Making Predictions with Data 1.txt
# Making Predictions with Data 2.txt
# Making Predictions with Data 3.txt
# Natural Language Processing 1.txt
# Natural Language Processing 2.txt
# Natural Language Processing 3.txt
# Neural Networks 1.txt
# Neural Networks 2.txt
# Neural Networks 3.txt
# Preparing Data With Pandas Part 1 - 1.txt
# Preparing Data With Pandas Part 1 - 2.txt
# Preparing Data With Pandas Part 1 - 3.txt
# Preparing Data With Pandas Part 2 - 1.txt
# Preparing Data With Pandas Part 2 - 2.txt
# Preparing Data With Pandas Part 2 - 3.txt
# Programming for AI Part 1 - 1.txt
# Programming for AI Part 1 - 2.txt
# Programming for AI Part 1 - 3.txt
# Programming for AI Part 2 - 1.txt
# Programming for AI Part 2 - 2.txt
# Programming for AI Part 2 - 3.txt
# Project 1 Week 1.txt
# Sourcing Data for AI Projects 1.txt
# Sourcing Data for AI Projects 2.txt
# Sourcing Data for AI Projects 3.txt
# Supervised Learning - Classification 1.txt
# Supervised Learning - Classification 2.txt
# Supervised Learning - Classification 3.txt
# Supervised Learning - Linear Regression 1.txt
# Supervised Learning - Linear Regression 2.txt
# Supervised Learning - Linear Regression 3.txt
# Transformers 1.txt
# Transformers 2 Julia.txt
# Transformers 3.txt
# Unsupervised Learning 1.txt
# Unsupervised Learning 2.txt
# Unsupervised Learning 3.txt

# %%
# Import our dependencies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %%
# Import the sample data
df = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m18/lesson_1/datasets/sample-data-5000.csv")

# Plot the sample data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <Axes: xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Separate the X and y
X = df.drop(columns="Target")
y = df["Target"]

# Use sklearn to split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Set input nodes to the number of features
input_nodes = len(X.columns)

# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=input_nodes))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 15
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 21 (84.00 Byte)
# Trainable params: 21 (84.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 118/118 [==============================] - 2s 3ms/step - loss: 0.8071 - accuracy: 0.3581
# Epoch 2/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.6789 - accuracy: 0.5627
# Epoch 3/50
# 118/118 [==============================] - 1s 4ms/step - loss: 0.5711 - accuracy: 0.7328
# Epoch 4/50
# 118/118 [==============================] - 1s 5ms/step - loss: 0.4677 - accuracy: 0.8523
# Epoch 5/50
# 118/118 [==============================] - 1s 4ms/step - loss: 0.3701 - accuracy: 0.9125
# Epoch 6/50
# 118/118 [==============================] - 1s 5ms/step - loss: 0.2928 - accuracy: 0.9253
# Epoch 7/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.2401 - accuracy: 0.9320
# Epoch 8/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.2051 - accuracy: 0.9355
# Epoch 9/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1815 - accuracy: 0.9397
# Epoch 10/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1653 - accuracy: 0.9416
# Epoch 11/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1538 - accuracy: 0.9432
# Epoch 12/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1456 - accuracy: 0.9464
# Epoch 13/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1395 - accuracy: 0.9483
# Epoch 14/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1351 - accuracy: 0.9504
# Epoch 15/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1318 - accuracy: 0.9520
# Epoch 16/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1294 - accuracy: 0.9515
# Epoch 17/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1276 - accuracy: 0.9520
# Epoch 18/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1263 - accuracy: 0.9525
# Epoch 19/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 0.9517
# Epoch 20/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1248 - accuracy: 0.9515
# Epoch 21/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1242 - accuracy: 0.9515
# Epoch 22/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1239 - accuracy: 0.9509
# Epoch 23/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1236 - accuracy: 0.9504
# Epoch 24/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1235 - accuracy: 0.9504
# Epoch 25/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1234 - accuracy: 0.9501
# Epoch 26/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1233 - accuracy: 0.9499
# Epoch 27/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1232 - accuracy: 0.9504
# Epoch 28/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.9504
# Epoch 29/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9507
# Epoch 30/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.9507
# Epoch 31/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1230 - accuracy: 0.9507
# Epoch 32/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.9504
# Epoch 33/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1230 - accuracy: 0.9507
# Epoch 34/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.9509
# Epoch 35/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1230 - accuracy: 0.9509
# Epoch 36/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.9509
# Epoch 37/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1228 - accuracy: 0.9509
# Epoch 38/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1228 - accuracy: 0.9512
# Epoch 39/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.9507
# Epoch 40/50
# 118/118 [==============================] - 1s 4ms/step - loss: 0.1227 - accuracy: 0.9512
# Epoch 41/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1227 - accuracy: 0.9509
# Epoch 42/50
# 118/118 [==============================] - 1s 4ms/step - loss: 0.1227 - accuracy: 0.9517
# Epoch 43/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.9509
# Epoch 44/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.9512
# Epoch 45/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.9504
# Epoch 46/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.9512
# Epoch 47/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 0.9507
# Epoch 48/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 0.9509
# Epoch 49/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 0.9509
# Epoch 50/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1225 - accuracy: 0.9512

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 40/40 - 0s - loss: 0.1228 - accuracy: 0.9520 - 201ms/epoch - 5ms/step
# Loss: 0.1228090301156044, Accuracy: 0.9520000219345093

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <Axes: >

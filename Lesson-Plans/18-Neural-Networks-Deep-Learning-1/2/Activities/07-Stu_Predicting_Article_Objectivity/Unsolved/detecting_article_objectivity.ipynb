# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pathlib import Path
import pandas as pd
import tensorflow as tf
from sklearn.metrics import classification_report

# %%
# Import data
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lesson_2/datasets/sports-articles.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#        Label  totalWordsCount  semanticobjscore  semanticsubjscore  CC  CD  \
# 0  objective              109                 0                  1   7   9
# 1  objective              309                21                  4   1  19
# 2  objective              149                 6                  1   8  14
# 3  objective              305                18                  5   7  26
# 4  objective              491                23                  8  33  47
#
#    DT  EX  FW  INs  ...  pronouns2nd  pronouns3rd  compsupadjadv  past  \
# 0   0   5   8    6  ...            0            3              0    11
# 1   1   4  35   23  ...            0           10              0    13
# 2   0   5  15   11  ...            0            2              0     8
# 3   0  10  37   21  ...            0            8              3    13
# 4   0  12  61   36  ...            0           16              2    34
#
#    imperative  present3rd  present1st2nd  sentence1st  sentencelast  \
# 0           0           0              0            0             1
# 1           0          14              9            1             1
# 2           0           3              2            1             1
# 3           1           7              1            1             1
# 4           1           5              6            1             1
#
#    txtcomplexity
# 0             18
# 1             14
# 2             18
# 3             20
# 4             24
#
# [5 rows x 60 columns]

# %%
# Drop the label to create the X data
X = df.drop('Label', axis=1)
# Create the y set from the "Label" column
y = df["Label"]

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Encode the y data with the label encoder
# Create an instance of the label encoder
le = LabelEncoder()

# Fit and transform the y training and testing data using the label encoder
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# %%
# Scale the X data by using StandardScaler()
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Define the deep learning model


# Compile the Sequential model together and customize metrics


# Train the model


# Evaluate the model using the test data
# Out:
# Epoch 1/100
# 24/24 [==============================] - 4s 9ms/step - loss: 0.6411 - accuracy: 0.6213
# Epoch 2/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6073 - accuracy: 0.6347
# Epoch 3/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.5807 - accuracy: 0.6360
# Epoch 4/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.5588 - accuracy: 0.6387
# Epoch 5/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.5431 - accuracy: 0.6387
# Epoch 6/100
# 24/24 [==============================] - 0s 11ms/step - loss: 0.5294 - accuracy: 0.6387
# Epoch 7/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5193 - accuracy: 0.6413
# Epoch 8/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5070 - accuracy: 0.6533
# Epoch 9/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.4953 - accuracy: 0.8187
# Epoch 10/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4864 - accuracy: 0.8307
# Epoch 11/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4787 - accuracy: 0.8333
# Epoch 12/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4718 - accuracy: 0.8373
# Epoch 13/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4658 - accuracy: 0.8427
# Epoch 14/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4602 - accuracy: 0.8507
# Epoch 15/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4540 - accuracy: 0.8547
# Epoch 16/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4490 - accuracy: 0.8587
# Epoch 17/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.4445 - accuracy: 0.8587
# Epoch 18/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4401 - accuracy: 0.8627
# Epoch 19/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4360 - accuracy: 0.8627
# Epoch 20/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4316 - accuracy: 0.8627
# Epoch 21/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4279 - accuracy: 0.8680
# Epoch 22/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.4232 - accuracy: 0.8707
# Epoch 23/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4193 - accuracy: 0.8693
# Epoch 24/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4118 - accuracy: 0.8733
# Epoch 25/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4003 - accuracy: 0.8733
# Epoch 26/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3895 - accuracy: 0.8747
# Epoch 27/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3789 - accuracy: 0.8760
# Epoch 28/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3692 - accuracy: 0.8760
# Epoch 29/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3633 - accuracy: 0.8773
# Epoch 30/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3603 - accuracy: 0.8733
# Epoch 31/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3549 - accuracy: 0.8760
# Epoch 32/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3499 - accuracy: 0.8787
# Epoch 33/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3485 - accuracy: 0.8800
# Epoch 34/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3483 - accuracy: 0.8787
# Epoch 35/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3430 - accuracy: 0.8827
# Epoch 36/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3405 - accuracy: 0.8827
# Epoch 37/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3380 - accuracy: 0.8853
# Epoch 38/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3395 - accuracy: 0.8827
# Epoch 39/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3354 - accuracy: 0.8867
# Epoch 40/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3337 - accuracy: 0.8867
# Epoch 41/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3314 - accuracy: 0.8880
# Epoch 42/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3281 - accuracy: 0.8933
# Epoch 43/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3294 - accuracy: 0.8907
# Epoch 44/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3270 - accuracy: 0.8920
# Epoch 45/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3248 - accuracy: 0.8960
# Epoch 46/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3244 - accuracy: 0.8947
# Epoch 47/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3227 - accuracy: 0.8960
# Epoch 48/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3218 - accuracy: 0.8987
# Epoch 49/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3219 - accuracy: 0.8947
# Epoch 50/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3206 - accuracy: 0.8960
# Epoch 51/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3186 - accuracy: 0.9013
# Epoch 52/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3185 - accuracy: 0.9013
# Epoch 53/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3178 - accuracy: 0.9013
# Epoch 54/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3184 - accuracy: 0.8973
# Epoch 55/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3157 - accuracy: 0.9000
# Epoch 56/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3155 - accuracy: 0.9013
# Epoch 57/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3147 - accuracy: 0.9040
# Epoch 58/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3139 - accuracy: 0.9053
# Epoch 59/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3129 - accuracy: 0.9040
# Epoch 60/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3130 - accuracy: 0.9040
# Epoch 61/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3115 - accuracy: 0.9053
# Epoch 62/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3109 - accuracy: 0.9053
# Epoch 63/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3098 - accuracy: 0.9053
# Epoch 64/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3129 - accuracy: 0.9013
# Epoch 65/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3087 - accuracy: 0.9053
# Epoch 66/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3074 - accuracy: 0.9080
# Epoch 67/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3085 - accuracy: 0.9000
# Epoch 68/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3067 - accuracy: 0.9080
# Epoch 69/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3055 - accuracy: 0.9053
# Epoch 70/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3056 - accuracy: 0.9067
# Epoch 71/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3075 - accuracy: 0.9040
# Epoch 72/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3040 - accuracy: 0.9053
# Epoch 73/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3027 - accuracy: 0.9053
# Epoch 74/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3023 - accuracy: 0.9080
# Epoch 75/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3023 - accuracy: 0.9040
# Epoch 76/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3014 - accuracy: 0.9067
# Epoch 77/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3009 - accuracy: 0.9053
# Epoch 78/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3004 - accuracy: 0.9080
# Epoch 79/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2986 - accuracy: 0.9053
# Epoch 80/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2984 - accuracy: 0.9067
# Epoch 81/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2977 - accuracy: 0.9080
# Epoch 82/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2958 - accuracy: 0.9093
# Epoch 83/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2950 - accuracy: 0.9107
# Epoch 84/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2948 - accuracy: 0.9107
# Epoch 85/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2930 - accuracy: 0.9133
# Epoch 86/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2980 - accuracy: 0.9053
# Epoch 87/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2940 - accuracy: 0.9120
# Epoch 88/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2920 - accuracy: 0.9120
# Epoch 89/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2933 - accuracy: 0.9093
# Epoch 90/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2902 - accuracy: 0.9107
# Epoch 91/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2900 - accuracy: 0.9120
# Epoch 92/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2884 - accuracy: 0.9133
# Epoch 93/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2951 - accuracy: 0.9080
# Epoch 94/100
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2948 - accuracy: 0.9013
# Epoch 95/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2909 - accuracy: 0.9093
# Epoch 96/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2863 - accuracy: 0.9120
# Epoch 97/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2861 - accuracy: 0.9120
# Epoch 98/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2853 - accuracy: 0.9120
# Epoch 99/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2838 - accuracy: 0.9133
# Epoch 100/100
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2834 - accuracy: 0.9120
# 8/8 - 0s - loss: 0.3958 - accuracy: 0.8520 - 196ms/epoch - 24ms/step
# Loss: 0.3957773447036743, Accuracy: 0.8519999980926514

# %%
# Make predictions with the test data
# Out:
# 8/8 - 0s - 165ms/epoch - 21ms/step
# array([[0.04768256],
#        [0.8712387 ],
#        [0.06608576],
#        [0.04040096],
#        [0.05782378],
#        [0.06307828],
#        [0.03615299],
#        [0.83192194],
#        [0.15982579],
#        [0.04308042],
#        [0.8501279 ],
#        [0.02818173],
#        [0.8994691 ],
#        [0.06389347],
#        [0.93749654],
#        [0.03639435],
#        [0.06396974],
#        [0.03408832],
#        [0.9424363 ],
#        [0.05859023],
#        [0.8393935 ],
#        [0.06087593],
#        [0.05484806],
#        [0.02885764],
#        [0.05348978],
#        [0.06496347],
#        [0.03256011],
#        [0.4758679 ],
#        [0.06638648],
#        [0.05139656],
#        [0.3915463 ],
#        [0.9109349 ],
#        [0.04571876],
#        [0.08937305],
#        [0.02921589],
#        [0.07310364],
#        [0.05496366],
#        [0.8599458 ],
#        [0.93489313],
#        [0.04665782],
#        [0.9412564 ],
#        [0.8116862 ],
#        [0.04938886],
#        [0.05121539],
#        [0.0682692 ],
#        [0.03121229],
#        [0.03988929],
#        [0.08387078],
#        [0.92421305],
#        [0.93781155],
#        [0.7613495 ],
#        [0.06350978],
#        [0.8939563 ],
#        [0.03012688],
#        [0.0345179 ],
#        [0.05079528],
#        [0.83764327],
#        [0.7853508 ],
#        [0.03468238],
#        [0.8023323 ],
#        [0.1458548 ],
#        [0.87212265],
#        [0.04082796],
#        [0.1628422 ],
#        [0.64420855],
#        [0.7647614 ],
#        [0.07643057],
#        [0.05351338],
#        [0.938343  ],
#        [0.04000955],
#        [0.94376445],
#        [0.86010665],
#        [0.8359743 ],
#        [0.751119  ],
#        [0.04259577],
#        [0.06563092],
#        [0.03571219],
#        [0.8881425 ],
#        [0.02852719],
#        [0.42403352],
#        [0.0742849 ],
#        [0.93412095],
#        [0.03108238],
#        [0.94273037],
#        [0.45387375],
#        [0.06073432],
#        [0.90278566],
#        [0.9118933 ],
#        [0.06943753],
#        [0.39597717],
#        [0.942612  ],
#        [0.05534881],
#        [0.04073166],
#        [0.9392909 ],
#        [0.03631811],
#        [0.92153186],
#        [0.05412213],
#        [0.9372198 ],
#        [0.24361265],
#        [0.7939201 ],
#        [0.2049148 ],
#        [0.07482541],
#        [0.88434434],
#        [0.7948207 ],
#        [0.40395465],
#        [0.07009644],
#        [0.03756211],
#        [0.04421621],
#        [0.85186094],
#        [0.9335265 ],
#        [0.04285358],
#        [0.94511837],
#        [0.84618473],
#        [0.07133624],
#        [0.9329398 ],
#        [0.09802449],
#        [0.91282606],
#        [0.34877017],
#        [0.03916395],
#        [0.9456049 ],
#        [0.02968037],
#        [0.05803142],
#        [0.03745143],
#        [0.0337182 ],
#        [0.04014897],
#        [0.75936556],
#        [0.7673348 ],
#        [0.9325457 ],
#        [0.06266168],
#        [0.9161076 ],
#        [0.04022988],
#        [0.68188477],
#        [0.8774867 ],
#        [0.05652112],
#        [0.88639313],
#        [0.9373895 ],
#        [0.71069354],
#        [0.44908985],
#        [0.03030987],
#        [0.8727705 ],
#        [0.038836  ],
#        [0.06412656],
#        [0.07515783],
#        [0.7311333 ],
#        [0.06027268],
#        [0.04394767],
#        [0.03097925],
#        [0.7405147 ],
#        [0.03516395],
#        [0.04774393],
#        [0.17294301],
#        [0.05428361],
#        [0.03282067],
#        [0.90327066],
#        [0.4377643 ],
#        [0.09308556],
#        [0.9342934 ],
#        [0.8772556 ],
#        [0.03498241],
#        [0.03569942],
#        [0.12377323],
#        [0.052802  ],
#        [0.07312583],
#        [0.9339422 ],
#        [0.9015642 ],
#        [0.0879349 ],
#        [0.06569247],
#        [0.9150967 ],
#        [0.06168183],
#        [0.14529349],
#        [0.04775837],
#        [0.07662653],
#        [0.03452173],
#        [0.05045728],
#        [0.03289166],
#        [0.06451003],
#        [0.13601564],
#        [0.38463485],
#        [0.6944537 ],
#        [0.9180806 ],
#        [0.13374783],
#        [0.07273757],
#        [0.81153345],
#        [0.9411983 ],
#        [0.6042175 ],
#        [0.03257542],
#        [0.03646643],
#        [0.06958872],
#        [0.11293133],
#        [0.89798427],
#        [0.8192048 ],
#        [0.94295454],
#        [0.04890893],
#        [0.06356551],
#        [0.5114014 ],
#        [0.05910101],
#        [0.46131507],
#        [0.0389312 ],
#        [0.1882941 ],
#        [0.09716602],
#        [0.07659549],
#        [0.88967943],
#        [0.9220306 ],
#        [0.03304506],
#        [0.0425167 ],
#        [0.8022374 ],
#        [0.04148866],
#        [0.06151245],
#        [0.04354906],
#        [0.4085566 ],
#        [0.9203765 ],
#        [0.0304885 ],
#        [0.88297755],
#        [0.03272453],
#        [0.8942137 ],
#        [0.09650824],
#        [0.05383324],
#        [0.118765  ],
#        [0.03906034],
#        [0.05090791],
#        [0.12371488],
#        [0.93520695],
#        [0.04098124],
#        [0.83451426],
#        [0.04436397],
#        [0.05489193],
#        [0.19189337],
#        [0.9295707 ],
#        [0.79767627],
#        [0.8578195 ],
#        [0.05122059],
#        [0.09200781],
#        [0.91607285],
#        [0.34056464],
#        [0.9357816 ],
#        [0.9420176 ],
#        [0.87665945],
#        [0.86662245],
#        [0.04126027],
#        [0.44999215],
#        [0.03717519],
#        [0.04743307],
#        [0.02891353],
#        [0.89606875],
#        [0.87094903],
#        [0.03488811],
#        [0.87501425],
#        [0.06069351],
#        [0.04849939],
#        [0.02883442]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
# Out:
#      predictions
# 0            0.0
# 1            1.0
# 2            0.0
# 3            0.0
# 4            0.0
# ..           ...
# 245          0.0
# 246          1.0
# 247          0.0
# 248          0.0
# 249          0.0
#
# [250 rows x 1 columns]

# %%
# Print the classification report with the y test data and predictions
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88       157
#            1       0.80      0.80      0.80        93
#
#     accuracy                           0.85       250
#    macro avg       0.84      0.84      0.84       250
# weighted avg       0.85      0.85      0.85       250

# %% [markdown]
# ## Save the Model

# %%
# Set the model's file path


# Export your model to a keras file

# %% [markdown]
# ## Load the Model

# %%
# Set the model's file path


# Load the model to a new object

# %%
# Evaluate the model using the test data


# Display evaluation results
# Out:
# 8/8 - 0s - loss: 0.3958 - accuracy: 0.8520 - 235ms/epoch - 29ms/step
# Loss: 0.3957773447036743, Accuracy: 0.8519999980926514

# %%
import pandas as pd
import pipeline_utilities as p_util

# %%
# Create a list of DataFrames by using a list comprehension with read_csv
days = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Saturday']
dfs = [pd.read_csv(f'https://static.bc-edx.com/ai/ail-v-1-0/m12/lesson_3/datasets/garments-worker-productivity-{day}.csv') for day in days]
dfs[-1].head()
# Out:
#        date   quarter  department       day  team  targeted_productivity  \
# 0  1/3/2015  Quarter1  finishing   Saturday     4                   0.80
# 1  1/3/2015  Quarter1  finishing   Saturday    11                   0.75
# 2  1/3/2015  Quarter1  finishing   Saturday     9                   0.80
# 3  1/3/2015  Quarter1  finishing   Saturday     3                   0.75
# 4  1/3/2015  Quarter1  finishing   Saturday     1                   0.80
#
#     smv  wip  over_time  incentive  idle_time  idle_men  no_of_style_change  \
# 0  4.15  NaN       6600          0        0.0         0                   0
# 1  2.90  NaN       5640          0        0.0         0                   0
# 2  4.15  NaN        960          0        0.0         0                   0
# 3  3.94  NaN       1560          0        0.0         0                   0
# 4  3.94  NaN        960          0        0.0         0                   0
#
#    no_of_workers  actual_productivity
# 0           20.0             0.988025
# 1           17.0             0.987880
# 2            8.0             0.956271
# 3            8.0             0.945278
# 4            8.0             0.902917

# %%
# Create a dictionary with the models
model_dict = {}
for df in dfs:
    print(df.iloc[0,3])
    model_dict[f"{df.iloc[0,3]}_model"] = p_util.prod_model_generator(df)
    print("----------")
# Out:
# Sunday
# Mean Squared Error: 0.005344883625468161
# R-squared: 0.7179867749346798
# Adjusted R-squared: 0.7075418406730012
# ----------
# Monday
# Mean Squared Error: 0.007744854059484582
# R-squared: 0.6359919195812382
# Adjusted R-squared: 0.6225101388249878
# ----------
# Tuesday
# Mean Squared Error: 0.004332975859075804
# R-squared: 0.7899217489167911
# Adjusted R-squared: 0.782418954235248
# ----------
# Wednesday
# Mean Squared Error: 0.01013226689654805
# R-squared: 0.6247579724036239
# Adjusted R-squared: 0.6113564714180391
# ----------
# Thursday
# Mean Squared Error: 0.015191141871080303
# R-squared: 0.5846240014721664
# Adjusted R-squared: 0.5697891443818867
# ----------
# Saturday
# Mean Squared Error: 0.006823266812409238
# R-squared: 0.7439240500826445
# Adjusted R-squared: 0.733254218836088
# ----------

# %%
model_dict
# Out:
# {'Sunday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', LinearRegression())]),
#  'Monday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', LinearRegression())]),
#  'Tuesday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', LinearRegression())]),
#  'Wednesday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', LinearRegression())]),
#  'Thursday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', LinearRegression())]),
#  'Saturday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', LinearRegression())])}

# %%
# Dependencies
import json
import requests
import pandas as pd

# %%
# Open library results limit to 50 results per page. 
# Authors documentation: https://openlibrary.org/dev/docs/api/authors
# URL for Neil Gaiman
url = "https://openlibrary.org/authors/OL53305A/works.json"

# %%
# Create an empty list to store the responses
response_json = []

# %%
# Make a request for 3 pages of results


    # Get the results


    # Loop through the "entries" of the results and
    # append them to the response_json list

        # Save post's JSON
# Out:
# Making request number: 0
# Making request number: 1
# Making request number: 2

# %%
# Now we have 150 book objects, 
# which we got by making 3 requests to the API.
# Out:
# We have 150 books!

# %%
# preview the JSON
print(json.dumps(response_json, indent=4))
# Out:
# [
#     {
#         "subjects": [
#             "Vampires",
#             "Fiction",
#             "Fiction, fantasy, historical"
#         ],
#         "key": "/works/OL15168890W",
#         "title": "By Blood We Live",
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL7207957A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL39486A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL23207A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL7202539A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL3003153A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL3023955A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL382982A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2711187A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL246532A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL381615A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL3042054A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1606907A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL9689655A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL220575A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL40965A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL18722A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL7752487A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL23918A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL9080029A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL397402A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1394972A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2645208A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL36575A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL1432654A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL2711189A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL7159378A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL340770A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL33124A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL577531A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL24812A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "type": {
#             "key": "/type/work"
#         },
#         "covers": [
#             6426138
#         ],
#         "latest_revision": 6,
#         "revision": 6,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2010-06-28T01:51:41.310258"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-26T17:08:55.936426"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Neverwhere",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7992934A"
#                 }
#             }
#         ],
#         "covers": [
#             13921349
#         ],
#         "key": "/works/OL34971926W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-13T02:59:43.364787"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "La \u00faltima tentaci\u00f3n",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9887914A"
#                 }
#             }
#         ],
#         "covers": [
#             14022824
#         ],
#         "key": "/works/OL35052442W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-15T18:25:29.580405"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Esposas prohibidas de siervos sin rostro",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL8154081A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9887914A"
#                 }
#             }
#         ],
#         "covers": [
#             14022878
#         ],
#         "key": "/works/OL35052472W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-15T18:27:06.008100"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "American Gods Sombras Tomo n\u00ba 01/03",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7992933A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1398733A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7040892A"
#                 }
#             }
#         ],
#         "covers": [
#             13944926
#         ],
#         "key": "/works/OL34989693W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-13T18:40:50.340106"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Los hijos de Anansi",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7992934A"
#                 }
#             }
#         ],
#         "covers": [
#             13921346
#         ],
#         "key": "/works/OL34971923W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-13T02:59:36.536032"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Coraline",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL12637877A"
#                 }
#             }
#         ],
#         "covers": [
#             14171423
#         ],
#         "key": "/works/OL35166343W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-19T11:52:32.000959"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "El puente del Troll",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL6456573A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9887914A"
#                 }
#             }
#         ],
#         "covers": [
#             14022787
#         ],
#         "key": "/works/OL35052410W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-15T18:24:34.057457"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Lovecraft's Monsters",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7161310A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9156684A"
#                 }
#             }
#         ],
#         "covers": [
#             13710809
#         ],
#         "key": "/works/OL34904042W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-03-20T14:58:06.826086"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Trigger Warning",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             14290096
#         ],
#         "key": "/works/OL35257256W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-21T12:00:42.741368"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "American Gods Sombras Tomo n\u00ba 03/03",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7992933A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1398733A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7040892A"
#                 }
#             }
#         ],
#         "covers": [
#             14021996
#         ],
#         "key": "/works/OL35051751W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-15T18:00:28.290494"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "\u00d6yk\u00fcler",
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL711630A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "covers": [
#             12126273
#         ],
#         "key": "/works/OL26166841W",
#         "latest_revision": 3,
#         "revision": 3,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2021-10-19T18:12:36.256835"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Invocaciones",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7981556A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9943041A"
#                 }
#             }
#         ],
#         "covers": [
#             13919642
#         ],
#         "key": "/works/OL34970662W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-13T01:31:26.790090"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "L'al.lucinant, gal\u00e0ctic i pir\u00e0tic viatge del pare",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL8211279A"
#                 }
#             }
#         ],
#         "covers": [
#             14080291
#         ],
#         "key": "/works/OL35096964W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-17T05:13:47.418823"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "American Gods Sombras n\u00ba 03/09",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1398733A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7040892A"
#                 }
#             }
#         ],
#         "covers": [
#             13945049
#         ],
#         "key": "/works/OL34989790W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-13T18:46:53.692443"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Trigger Warning",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             14290099
#         ],
#         "key": "/works/OL35257259W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-21T12:00:42.956074"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "LOS ETERNOS. DEL G\u00c9NESIS AL APOCALIPSIS 8",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2864376A"
#                 }
#             }
#         ],
#         "covers": [
#             13705881
#         ],
#         "key": "/works/OL34900197W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-03-20T12:05:47.238013"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Coraline",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7824837A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL12531583A"
#                 }
#             }
#         ],
#         "covers": [
#             14016344
#         ],
#         "key": "/works/OL35047501W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-15T14:22:00.217009"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "El problema de Susan y otras historias",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7992933A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1398733A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL5464219A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7040892A"
#                 }
#             }
#         ],
#         "covers": [
#             14021989
#         ],
#         "key": "/works/OL35051747W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-15T18:00:16.490828"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "La \u00faltima tentaci\u00f3n",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9887914A"
#                 }
#             }
#         ],
#         "covers": [
#             14022823
#         ],
#         "key": "/works/OL35052441W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-15T18:25:29.579480"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Trigger Warning",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             14290098
#         ],
#         "key": "/works/OL35257258W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-21T12:00:42.960509"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "American Gods Sombras n\u00ba 04/09",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7040892A"
#                 }
#             }
#         ],
#         "covers": [
#             13945042
#         ],
#         "key": "/works/OL34989784W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-13T18:46:38.303208"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Coraline, Lingua Basco",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL219070A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL12531583A"
#                 }
#             }
#         ],
#         "covers": [
#             14216851
#         ],
#         "key": "/works/OL35200486W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-20T03:59:55.885209"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Violent Cases",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2630661A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7040892A"
#                 }
#             }
#         ],
#         "covers": [
#             13944957
#         ],
#         "key": "/works/OL34989722W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-13T18:42:19.564865"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "El cementiri sense l\u00e0pides i altres hist\u00f2ries negres",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL12692617A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9228882A"
#                 }
#             }
#         ],
#         "covers": [
#             14080907
#         ],
#         "key": "/works/OL35097447W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-17T05:29:41.594995"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Stardust",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7525857A"
#                 }
#             }
#         ],
#         "covers": [
#             13921339
#         ],
#         "key": "/works/OL34971920W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-13T02:59:29.742371"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Bons averanys",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL10824473A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             13934443
#         ],
#         "key": "/works/OL34981844W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-13T10:44:44.232146"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Esposas prohibidas de siervos sin rostro",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL8154081A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9887914A"
#                 }
#             }
#         ],
#         "covers": [
#             14022877
#         ],
#         "key": "/works/OL35052471W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-15T18:27:05.990803"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "American Gods Sombras n\u00ba 09/09",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7992933A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1398733A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7040892A"
#                 }
#             }
#         ],
#         "covers": [
#             13944967
#         ],
#         "key": "/works/OL34989730W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-13T18:42:50.919830"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Mitos n\u00f3rdicos n\u00ba 02/03",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7992933A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2864353A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7040892A"
#                 }
#             }
#         ],
#         "covers": [
#             14021988
#         ],
#         "key": "/works/OL35051746W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-15T18:00:13.123190"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "American Gods Sombras Tomo n\u00ba 02/03",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7992933A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1398733A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7040892A"
#                 }
#             }
#         ],
#         "covers": [
#             13944665
#         ],
#         "key": "/works/OL34989496W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-13T18:31:00.730419"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Dustcovers",
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL219070A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "key": "/works/OL31645681W",
#         "subjects": [
#             "Comic book covers",
#             "Graphic novels",
#             "Illustrations",
#             "Book jackets"
#         ],
#         "covers": [
#             13598489
#         ],
#         "latest_revision": 4,
#         "revision": 4,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-12-08T07:37:57.893403"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Sandman",
#         "key": "/works/OL35374512W",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T01:06:56.860312"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Mitos n\u00f3rdicos n\u00ba 02/03",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7992933A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2864353A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7040892A"
#                 }
#             }
#         ],
#         "covers": [
#             14021987
#         ],
#         "key": "/works/OL35051745W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-15T18:00:13.122166"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Trigger Warning",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             14290097
#         ],
#         "key": "/works/OL35257257W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-21T12:00:42.776700"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Els 13 rellotges",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9984045A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL10139968A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL4210497A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             14192180
#         ],
#         "key": "/works/OL35181461W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-19T20:44:47.337265"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Sandman : Edici\u00f3n Deluxe vol. 0",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9385227A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9117709A"
#                 }
#             }
#         ],
#         "key": "/works/OL34966782W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-04-12T21:15:35.266992"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-05-18T15:50:54.692481"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Biblioteca Sandman vol. 13",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7993053A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL282954A"
#                 }
# ...
#             "value": "2022-09-18T01:01:11.861234"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Neil Gaiman's a Study in Emerald",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL3863529A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7633128A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2872020A"
#                 }
#             }
#         ],
#         "key": "/works/OL28828366W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-09-18T07:19:39.317204"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Blood Bank",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7583529A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL3027409A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL8225117A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7485067A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL11431059A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL1519822A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL8363228A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL9365779A"
#                 }
#             }
#         ],
#         "key": "/works/OL31341625W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-12-06T15:28:20.291884"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Absolute Sandman Overture (2023 Edition)",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2943948A"
#                 }
#             }
#         ],
#         "key": "/works/OL34498041W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-02-17T18:29:37.344576"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "AMER\u0130KAN TANRILARI",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL31967754W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-12-10T09:03:43.019897"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Sandman n\u00fam. 03",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL815884A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL670446A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL6456573A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL10828311A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7972109A"
#                 }
#             }
#         ],
#         "key": "/works/OL29288316W",
#         "covers": [
#             13537285
#         ],
#         "latest_revision": 3,
#         "revision": 3,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-11-11T23:57:30.759247"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Interworld",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL29239367W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-10-26T22:17:18.392922"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Neil Gaiman's Troll Bridge",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL28826973W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-09-18T06:36:47.895827"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Gwiezdny py\u0142",
#         "subjects": [
#             "Powie\u015b\u0107 fantastyczna angielska",
#             "T\u0142umaczenia polskie"
#         ],
#         "subject_times": [
#             "1990-"
#         ],
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             13022955
#         ],
#         "key": "/works/OL31212717W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-12-04T03:27:41.117716"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Bioluminescent",
#         "subjects": [
#             "Fiction, science fiction, general",
#             "Fiction, anthologies (multiple authors)",
#             "solarpunk"
#         ],
#         "authors": [
#             {
#                 "author": {
#                     "key": "/authors/OL10394934A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL7501009A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             },
#             {
#                 "author": {
#                     "key": "/authors/OL10802936A"
#                 },
#                 "type": {
#                     "key": "/type/author_role"
#                 }
#             }
#         ],
#         "key": "/works/OL29204484W",
#         "description": {
#             "type": "/type/text",
#             "value": "Solarpunk communities that glow when the sun goes down. Witches on distant planets and future pagans building resilient ecotopias. The search for hope in a better world. Evolution and transformation. Exploration and discovery. The pages of this book are filled with wonders both technological and magical. Conflicts lead to resilience and solutions both internal and community-based. Stories span from the terrestrial to the galactic to the inner-depths of memory and imagination.\r\n\r\nFeaturing work by Starhawk, Sarena Ulibarri, Wendy N. Wagner, Neil Gaiman, Justine Norton-Kertson, Yasmin Moita, J.D. Harklock, BrightFlame, Pedro Inguez, and more, twenty-two authors take a variety of different paths as they begin to map out the new and budding lunarpunk genre's terrain. Join them in adventures through glowing utopian worlds where people work together and do their best to build a better for us all. Join the, and explore Lunarpunk."
#         },
#         "latest_revision": 3,
#         "revision": 3,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-10-20T01:01:35.151616"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Monkey and Me",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL32372290W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-12-17T06:43:57.184924"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Sandman vol. 05",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL3132857A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL6456573A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL2910854A"
#                 }
#             },
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL7331524A"
#                 }
#             }
#         ],
#         "key": "/works/OL28759674W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-08-22T12:05:03.214085"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Creatures of the Night (Second Edition)",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "key": "/works/OL28828915W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2022-09-18T07:35:24.977849"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     },
#     {
#         "type": {
#             "key": "/type/work"
#         },
#         "title": "Dym i lustra",
#         "authors": [
#             {
#                 "type": {
#                     "key": "/type/author_role"
#                 },
#                 "author": {
#                     "key": "/authors/OL53305A"
#                 }
#             }
#         ],
#         "covers": [
#             13332556
#         ],
#         "key": "/works/OL34532681W",
#         "latest_revision": 2,
#         "revision": 2,
#         "created": {
#             "type": "/type/datetime",
#             "value": "2023-02-23T21:47:38.507991"
#         },
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2023-03-19T17:38:48.118928"
#         }
#     }
# ]

# %%
# Convert the results to a DataFrame
# Out:
#                                               subjects                 key  \
# 0    [Vampires, Fiction, Fiction, fantasy, historical]  /works/OL15168890W
# 1                                                  NaN  /works/OL34971926W
# 2                                                  NaN  /works/OL35052442W
# 3                                                  NaN  /works/OL35052472W
# 4                                                  NaN  /works/OL34989693W
# ..                                                 ...                 ...
# 145  [Fiction, science fiction, general, Fiction, a...  /works/OL29204484W
# 146                                                NaN  /works/OL32372290W
# 147                                                NaN  /works/OL28759674W
# 148                                                NaN  /works/OL28828915W
# 149                                                NaN  /works/OL34532681W
#
#                                         title  \
# 0                            By Blood We Live
# 1                                  Neverwhere
# 2                         La última tentación
# 3    Esposas prohibidas de siervos sin rostro
# 4         American Gods Sombras Tomo nº 01/03
# ..                                        ...
# 145                            Bioluminescent
# 146                             Monkey and Me
# 147                           Sandman vol. 05
# 148   Creatures of the Night (Second Edition)
# 149                              Dym i lustra
#
#                                                authors                   type  \
# 0    [{'author': {'key': '/authors/OL7207957A'}, 't...  {'key': '/type/work'}
# 1    [{'type': {'key': '/type/author_role'}, 'autho...  {'key': '/type/work'}
# 2    [{'type': {'key': '/type/author_role'}, 'autho...  {'key': '/type/work'}
# 3    [{'type': {'key': '/type/author_role'}, 'autho...  {'key': '/type/work'}
# 4    [{'type': {'key': '/type/author_role'}, 'autho...  {'key': '/type/work'}
# ..                                                 ...                    ...
# 145  [{'author': {'key': '/authors/OL10394934A'}, '...  {'key': '/type/work'}
# 146  [{'type': {'key': '/type/author_role'}, 'autho...  {'key': '/type/work'}
# 147  [{'type': {'key': '/type/author_role'}, 'autho...  {'key': '/type/work'}
# 148  [{'type': {'key': '/type/author_role'}, 'autho...  {'key': '/type/work'}
# 149  [{'type': {'key': '/type/author_role'}, 'autho...  {'key': '/type/work'}
#
#          covers  latest_revision  revision  \
# 0     [6426138]                6         6
# 1    [13921349]                2         2
# 2    [14022824]                2         2
# 3    [14022878]                2         2
# 4    [13944926]                2         2
# ..          ...              ...       ...
# 145         NaN                3         3
# 146         NaN                2         2
# 147         NaN                2         2
# 148         NaN                2         2
# 149  [13332556]                2         2
#
#                                                created  \
# 0    {'type': '/type/datetime', 'value': '2010-06-2...
# 1    {'type': '/type/datetime', 'value': '2023-04-1...
# 2    {'type': '/type/datetime', 'value': '2023-04-1...
# 3    {'type': '/type/datetime', 'value': '2023-04-1...
# 4    {'type': '/type/datetime', 'value': '2023-04-1...
# ..                                                 ...
# 145  {'type': '/type/datetime', 'value': '2022-10-2...
# 146  {'type': '/type/datetime', 'value': '2022-12-1...
# 147  {'type': '/type/datetime', 'value': '2022-08-2...
# 148  {'type': '/type/datetime', 'value': '2022-09-1...
# 149  {'type': '/type/datetime', 'value': '2023-02-2...
#
#                                          last_modified subtitle  \
# 0    {'type': '/type/datetime', 'value': '2023-05-2...      NaN
# 1    {'type': '/type/datetime', 'value': '2023-05-1...      NaN
# 2    {'type': '/type/datetime', 'value': '2023-05-1...      NaN
# 3    {'type': '/type/datetime', 'value': '2023-05-1...      NaN
# 4    {'type': '/type/datetime', 'value': '2023-05-1...      NaN
# ..                                                 ...      ...
# 145  {'type': '/type/datetime', 'value': '2023-03-1...      NaN
# 146  {'type': '/type/datetime', 'value': '2023-03-1...      NaN
# 147  {'type': '/type/datetime', 'value': '2023-03-1...      NaN
# 148  {'type': '/type/datetime', 'value': '2023-03-1...      NaN
# 149  {'type': '/type/datetime', 'value': '2023-03-1...      NaN
#
#                                            description first_publish_date  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4                                                  NaN                NaN
# ..                                                 ...                ...
# 145  {'type': '/type/text', 'value': 'Solarpunk com...                NaN
# 146                                                NaN                NaN
# 147                                                NaN                NaN
# 148                                                NaN                NaN
# 149                                                NaN                NaN
#
#     lc_classifications dewey_number subject_places subject_people  \
# 0                  NaN          NaN            NaN            NaN
# 1                  NaN          NaN            NaN            NaN
# 2                  NaN          NaN            NaN            NaN
# 3                  NaN          NaN            NaN            NaN
# 4                  NaN          NaN            NaN            NaN
# ..                 ...          ...            ...            ...
# 145                NaN          NaN            NaN            NaN
# 146                NaN          NaN            NaN            NaN
# 147                NaN          NaN            NaN            NaN
# 148                NaN          NaN            NaN            NaN
# 149                NaN          NaN            NaN            NaN
#
#     subject_times
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 145           NaN
# 146           NaN
# 147           NaN
# 148           NaN
# 149           NaN
#
# [150 rows x 18 columns]

# %%
# Convert the results to a DataFrame, normalizing the JSON
# Out:
#                                               subjects                 key  \
# 0    [Vampires, Fiction, Fiction, fantasy, historical]  /works/OL15168890W
# 1                                                  NaN  /works/OL34971926W
# 2                                                  NaN  /works/OL35052442W
# 3                                                  NaN  /works/OL35052472W
# 4                                                  NaN  /works/OL34989693W
# ..                                                 ...                 ...
# 145  [Fiction, science fiction, general, Fiction, a...  /works/OL29204484W
# 146                                                NaN  /works/OL32372290W
# 147                                                NaN  /works/OL28759674W
# 148                                                NaN  /works/OL28828915W
# 149                                                NaN  /works/OL34532681W
#
#                                         title  \
# 0                            By Blood We Live
# 1                                  Neverwhere
# 2                         La última tentación
# 3    Esposas prohibidas de siervos sin rostro
# 4         American Gods Sombras Tomo nº 01/03
# ..                                        ...
# 145                            Bioluminescent
# 146                             Monkey and Me
# 147                           Sandman vol. 05
# 148   Creatures of the Night (Second Edition)
# 149                              Dym i lustra
#
#                                                authors      covers  \
# 0    [{'author': {'key': '/authors/OL7207957A'}, 't...   [6426138]
# 1    [{'type': {'key': '/type/author_role'}, 'autho...  [13921349]
# 2    [{'type': {'key': '/type/author_role'}, 'autho...  [14022824]
# 3    [{'type': {'key': '/type/author_role'}, 'autho...  [14022878]
# 4    [{'type': {'key': '/type/author_role'}, 'autho...  [13944926]
# ..                                                 ...         ...
# 145  [{'author': {'key': '/authors/OL10394934A'}, '...         NaN
# 146  [{'type': {'key': '/type/author_role'}, 'autho...         NaN
# 147  [{'type': {'key': '/type/author_role'}, 'autho...         NaN
# 148  [{'type': {'key': '/type/author_role'}, 'autho...         NaN
# 149  [{'type': {'key': '/type/author_role'}, 'autho...  [13332556]
#
#      latest_revision  revision    type.key    created.type  \
# 0                  6         6  /type/work  /type/datetime
# 1                  2         2  /type/work  /type/datetime
# 2                  2         2  /type/work  /type/datetime
# 3                  2         2  /type/work  /type/datetime
# 4                  2         2  /type/work  /type/datetime
# ..               ...       ...         ...             ...
# 145                3         3  /type/work  /type/datetime
# 146                2         2  /type/work  /type/datetime
# 147                2         2  /type/work  /type/datetime
# 148                2         2  /type/work  /type/datetime
# 149                2         2  /type/work  /type/datetime
#
#                   created.value  ... subtitle description first_publish_date  \
# 0    2010-06-28T01:51:41.310258  ...      NaN         NaN                NaN
# 1    2023-04-13T02:59:43.364787  ...      NaN         NaN                NaN
# 2    2023-04-15T18:25:29.580405  ...      NaN         NaN                NaN
# 3    2023-04-15T18:27:06.008100  ...      NaN         NaN                NaN
# 4    2023-04-13T18:40:50.340106  ...      NaN         NaN                NaN
# ..                          ...  ...      ...         ...                ...
# 145  2022-10-20T01:01:35.151616  ...      NaN         NaN                NaN
# 146  2022-12-17T06:43:57.184924  ...      NaN         NaN                NaN
# 147  2022-08-22T12:05:03.214085  ...      NaN         NaN                NaN
# 148  2022-09-18T07:35:24.977849  ...      NaN         NaN                NaN
# 149  2023-02-23T21:47:38.507991  ...      NaN         NaN                NaN
#
#     lc_classifications dewey_number subject_places subject_people  \
# 0                  NaN          NaN            NaN            NaN
# 1                  NaN          NaN            NaN            NaN
# 2                  NaN          NaN            NaN            NaN
# 3                  NaN          NaN            NaN            NaN
# 4                  NaN          NaN            NaN            NaN
# ..                 ...          ...            ...            ...
# 145                NaN          NaN            NaN            NaN
# 146                NaN          NaN            NaN            NaN
# 147                NaN          NaN            NaN            NaN
# 148                NaN          NaN            NaN            NaN
# 149                NaN          NaN            NaN            NaN
#
#     description.type                                  description.value  \
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
# ..               ...                                                ...
# 145       /type/text  Solarpunk communities that glow when the sun g...
# 146              NaN                                                NaN
# 147              NaN                                                NaN
# 148              NaN                                                NaN
# 149              NaN                                                NaN
#
#     subject_times
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 145           NaN
# 146           NaN
# 147           NaN
# 148           NaN
# 149           NaN
#
# [150 rows x 22 columns]

# %%
# Export to CSV

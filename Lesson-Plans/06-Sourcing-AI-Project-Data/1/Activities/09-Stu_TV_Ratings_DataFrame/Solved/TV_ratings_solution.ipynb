# %%
# Dependencies
import requests
import pandas as pd

# %%
# list of TV show titles to query
tv_shows = ["Altered Carbon", "Grey's Anatomy", "This is Us", 
            "Stranger Things", "Family Law", "Good Omens",
            "Vikings", "Shameless", "Arrow", "Dirk Gently"]

# TV Maze show search base URL
base_url = "http://api.tvmaze.com/search/shows?q="

# set up lists to hold response data for name and rating
titles = []
ratings = []

all_results = []

# loop through TV show titles, make requests and parse
for show in tv_shows:
    target_url = base_url + show
    response = requests.get(target_url).json()
    titles.append(response[0]['show']['name'])
    ratings.append(response[0]['show']['rating']['average'])
    all_results.append(response[0]['show'])

# %%
# create DataFrame with titles and ratings
shows_df = pd.DataFrame({
    "title": titles,
    "rating": ratings
})

shows_df
# Out:
#              title  rating
# 0   Altered Carbon     8.0
# 1   Grey's Anatomy     7.7
# 2       This Is Us     7.9
# 3  Stranger Things     8.5
# 4       Family Law     5.8
# 5       Good Omens     7.9
# 6          Vikings     8.6
# 7        Shameless     8.5
# 8            Arrow     7.4
# 9      Dirk Gently     7.4

# %%
# Use json_normalize to convert all_results to a DataFrame
all_results_df = pd.json_normalize(all_results)
all_results_df
# Out:
#       id                                                url             name  \
# 0  12036  https://www.tvmaze.com/shows/12036/altered-carbon   Altered Carbon
# 1     67      https://www.tvmaze.com/shows/67/greys-anatomy   Grey's Anatomy
# 2  17128      https://www.tvmaze.com/shows/17128/this-is-us       This Is Us
# 3   2993  https://www.tvmaze.com/shows/2993/stranger-things  Stranger Things
# 4  49299      https://www.tvmaze.com/shows/49299/family-law       Family Law
# 5  28717      https://www.tvmaze.com/shows/28717/good-omens       Good Omens
# 6     29            https://www.tvmaze.com/shows/29/vikings          Vikings
# 7    150         https://www.tvmaze.com/shows/150/shameless        Shameless
# 8      4               https://www.tvmaze.com/shows/4/arrow            Arrow
# 9   3570      https://www.tvmaze.com/shows/3570/dirk-gently      Dirk Gently
#
#        type language                            genres            status  \
# 0  Scripted  English   [Drama, Crime, Science-Fiction]             Ended
# 1  Scripted  English         [Drama, Romance, Medical]           Running
# 2  Scripted  English          [Drama, Comedy, Romance]             Ended
# 3  Scripted  English  [Drama, Horror, Science-Fiction]           Running
# 4  Scripted  English            [Drama, Family, Legal]           Running
# 5  Scripted  English         [Comedy, Action, Fantasy]  To Be Determined
# 6  Scripted  English          [Drama, Action, History]             Ended
# 7  Scripted  English           [Drama, Comedy, Family]             Ended
# 8  Scripted  English  [Drama, Action, Science-Fiction]             Ended
# 9  Scripted  English            [Drama, Comedy, Crime]             Ended
#
#    runtime  averageRuntime   premiered  ...  \
# 0      NaN              52  2018-02-02  ...
# 1     60.0              60  2005-03-27  ...
# 2     60.0              60  2016-09-20  ...
# 3      NaN              62  2016-07-15  ...
# 4     60.0              60  2021-09-17  ...
# 5      NaN              52  2019-05-31  ...
# 6     60.0              60  2013-03-03  ...
# 7     60.0              60  2011-01-09  ...
# 8     60.0              60  2012-10-10  ...
# 9     55.0              55  2012-03-05  ...
#
#                      _links.self.href  \
# 0  https://api.tvmaze.com/shows/12036
# 1     https://api.tvmaze.com/shows/67
# 2  https://api.tvmaze.com/shows/17128
# 3   https://api.tvmaze.com/shows/2993
# 4  https://api.tvmaze.com/shows/49299
# 5  https://api.tvmaze.com/shows/28717
# 6     https://api.tvmaze.com/shows/29
# 7    https://api.tvmaze.com/shows/150
# 8      https://api.tvmaze.com/shows/4
# 9   https://api.tvmaze.com/shows/3570
#
#                _links.previousepisode.href  webChannel  network.id  \
# 0  https://api.tvmaze.com/episodes/2154820         NaN         NaN
# 1  https://api.tvmaze.com/episodes/2511128         NaN         3.0
# 2  https://api.tvmaze.com/episodes/2296682         NaN         1.0
# 3  https://api.tvmaze.com/episodes/2209857         NaN         NaN
# 4  https://api.tvmaze.com/episodes/2373607         NaN        67.0
# 5  https://api.tvmaze.com/episodes/2545197         NaN         NaN
# 6  https://api.tvmaze.com/episodes/1993646         NaN       118.0
# 7  https://api.tvmaze.com/episodes/2042851         NaN         9.0
# 8  https://api.tvmaze.com/episodes/1744752         NaN         5.0
# 9   https://api.tvmaze.com/episodes/233137         NaN        51.0
#
#   network.name network.country.name  network.country.code  \
# 0          NaN                  NaN                   NaN
# 1          ABC        United States                    US
# 2          NBC        United States                    US
# 3          NaN                  NaN                   NaN
# 4       Global               Canada                    CA
# 5          NaN                  NaN                   NaN
# 6      History               Canada                    CA
# 7     Showtime        United States                    US
# 8       The CW        United States                    US
# 9     BBC Four       United Kingdom                    GB
#
#   network.country.timezone           network.officialSite  \
# 0                      NaN                            NaN
# 1         America/New_York               https://abc.com/
# 2         America/New_York           https://www.nbc.com/
# 3                      NaN                            NaN
# 4          America/Halifax                           None
# 5                      NaN                            NaN
# 6          America/Halifax        https://www.history.ca/
# 7         America/New_York           https://www.sho.com/
# 8         America/New_York          https://www.cwtv.com/
# 9            Europe/London  https://www.bbc.co.uk/bbcfour
#
#                    _links.nextepisode.href
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4  https://api.tvmaze.com/episodes/2494043
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
#
# [10 rows x 39 columns]

# %%
# Export all_results_df to CSV
all_results_df.to_csv("all_results_df.csv", index=False)

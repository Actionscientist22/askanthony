# %%
# Required imports
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Load the Data Into a Pandas DataFrame

# %%
# Read in the CSV file as a Pandas Dataframe
ccinfo_default_df = pd.read_csv("Resources/ccinfo_transformed.csv")
# Show the DataFrame.
ccinfo_default_df.head()
# Out:
#    limit_bal  marriage  age  bill_amt   pay_amt  default  other  post-grad  \
# 0  -1.117341         1   24 -0.660703 -0.542779        1      0          0
# 1  -0.349942         0   26 -0.636370 -0.463994        1      0          0
# 2  -0.580162         0   34 -0.416808 -0.354013        0      0          0
# 3  -0.887121         1   37 -0.080152 -0.402077        0      0          0
# 4  -0.887121         1   57 -0.396855  0.523771        0      0          0
#
#    primary  secondary  customer_segments
# 0        0          1                  2
# 1        0          1                  2
# 2        0          1                  0
# 3        0          1                  0
# 4        0          1                  1

# %%
# Plot the clusters using the "limit_bal" and "age" columns
# Out:
# <Axes: xlabel='limit_bal', ylabel='age'>

# %%
# Plot the clusters using the "bill_amt" and "pay_amt" columns
# Out:
# <Axes: xlabel='bill_amt', ylabel='pay_amt'>

# %% [markdown]
# ## Normalize and Transform the Data

# %%
# Drop the customer_segments column so it isn't considered a feature.
# Out:
#    limit_bal  marriage  age  bill_amt   pay_amt  default  other  post-grad  \
# 0  -1.117341         1   24 -0.660703 -0.542779        1      0          0
# 1  -0.349942         0   26 -0.636370 -0.463994        1      0          0
# 2  -0.580162         0   34 -0.416808 -0.354013        0      0          0
# 3  -0.887121         1   37 -0.080152 -0.402077        0      0          0
# 4  -0.887121         1   57 -0.396855  0.523771        0      0          0
#
#    primary  secondary
# 0        0          1
# 1        0          1
# 2        0          1
# 3        0          1
# 4        0          1

# %%
# Import the PCA module

# %%
# Instantiate the PCA instance and declare the number of PCA variables

# %%
# Fit the PCA model on the transformed credit card DataFrame


# Review the first 5 rows of list data
# Out:
# array([[-11.37730727,  -1.17537801],
#        [ -9.3885373 ,  -0.72756683],
#        [ -1.39588756,  -0.78857801],
#        [  1.62350575,  -0.84822309],
#        [ 21.61671552,  -0.84767395]])

# %% [markdown]
# ## Get the Variance of Each Component

# %%
# Calculate the PCA explained variance ratio
# Out:
# array([0.95609968, 0.01907234])

# %% [markdown]
# ## Creating the PCA DataFrame

# %%
# Create the PCA DataFrame


# Review the PCA DataFrame
c
# Out:
#         PCA1      PCA2
# 0 -11.377307 -1.175378
# 1  -9.388537 -0.727567
# 2  -1.395888 -0.788578
# 3   1.623506 -0.848223
# 4  21.616716 -0.847674
# 5   1.598600 -0.749019
# 6  -6.263217  6.841229
# 7 -12.390534 -0.732948
# 8  -7.347906 -0.542217
# 9  -0.392949 -1.189718

# %% [markdown]
# ## Determine the Optimal `k` Value

# %%
# Create a a list to store inertia values and the values of k


# Append the value of the computed inertia from the `inertia_` attribute of teh KMeans model instance


# Define a DataFrame to hold the values for k and the corresponding inertia


# Review the DataFrame
# Out:
#    k        inertia
# 0  1  438255.349641
# 1  2  141755.819448
# 2  3   73116.011341
# 3  4   48176.955144
# 4  5   35632.113822

# %%
# Plot the Elbow Curve
# Out:
# <Axes: title={'center': 'Elbow Curve'}, xlabel='k'>

# %%
# Determine the rate of decrease between each k value
# Out:
# Percentage decrease from k=1 to k=2: 67.65%
# Percentage decrease from k=2 to k=3: 48.42%
# Percentage decrease from k=3 to k=4: 34.11%
# Percentage decrease from k=4 to k=5: 26.04%
# Percentage decrease from k=5 to k=6: 17.74%
# Percentage decrease from k=6 to k=7: 22.52%
# Percentage decrease from k=7 to k=8: 14.74%
# Percentage decrease from k=8 to k=9: 11.28%
# Percentage decrease from k=9 to k=10: 9.00%

# %% [markdown]
# ## Segmentation of the PCA data with K-means

# %%
# Define the model with 3 clusters


# Fit the model


# Make predictions


# Create a copy of the PCA DataFrame


# Add a class column with the labels

# %%
# Plot the clusters
# Out:
# <Axes: xlabel='PCA1', ylabel='PCA2'>

# %%
# What columns contribute the most to the explained variance?
# Calculate the PCA explained variance ratio
# Out:
# array([0.95609968, 0.01907234])

# %%
# Determine which feature has the stronger influence on each principal component. 
# Use the columns from the original DataFrame. FYI: The data has already been scaled and fitted.

# %% [markdown]
# ### Which features have the strongest influence on each component?
# ---

# %%
# Import the required libraries and dependencies
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Read the CSV file into a pandas DataFrame
# Set the index using the Ticker column
df_stocks = pd.read_csv("Resources/stock_data.csv", index_col="Ticker")

# Review the DataFrame
df_stocks.head()
# Out:
#             Company_Name   MeanOpen    MeanHigh    MeanLow   MeanClose  \
# Ticker
# AA                Alcoa   16.515833   16.950000  16.039167   16.549167
# AXP     American Express  44.602500   45.683333  43.615833   44.821667
# BA                Boeing  70.768333   72.375000  69.235000   71.258333
# BAC      Bank of America  14.302500   14.660000  13.867500   14.270000
# CAT          Caterpillar  99.521667  101.933333  97.073333  100.364167
#
#           MeanVolume  MeanPercentReturn       Sector
# Ticker
# AA      1.420218e+08           0.181467  Industrials
# AXP     3.849082e+07           0.401822   Financials
# BA      2.614144e+07           0.589636  Industrials
# BAC     8.283930e+08           0.070159   Financials
# CAT     3.093352e+07           0.439549  Industrials

# %%
# Get the information on the data types
df_stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, AA to XOM
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company_Name       30 non-null     object
#  1   MeanOpen           30 non-null     float64
#  2   MeanHigh           30 non-null     float64
#  3   MeanLow            30 non-null     float64
#  4   MeanClose          30 non-null     float64
#  5   MeanVolume         30 non-null     float64
#  6   MeanPercentReturn  30 non-null     float64
#  7   Sector             30 non-null     object
# dtypes: float64(6), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# ## Preprocess and Scale the Data

# %%
# Use the StandardScaler module and fit_transform function to 
# scale all columns with numerical values
stock_data_scaled = StandardScaler().fit_transform(df_stocks[["MeanOpen", "MeanHigh",
                                                              "MeanLow", "MeanClose",
                                                              "MeanVolume", "MeanPercentReturn"]])

# Display the first five rows of the scaled data
stock_data_scaled[0:5]
# Out:
# array([[-1.15888638, -1.15321656, -1.15962398, -1.15341696,  0.10318422,
#         -1.61091732],
#        [-0.26115681, -0.25439297, -0.26573893, -0.25818533, -0.53919946,
#         -0.91904186],
#        [ 0.57517748,  0.58056409,  0.56469466,  0.57891575, -0.61582422,
#         -0.32934221],
#        [-1.2296308 , -1.22485134, -1.23001756, -1.2255854 ,  4.36194457,
#         -1.96040239],
#        [ 1.49421562,  1.50519497,  1.46706151,  1.50053439, -0.58609062,
#         -0.80058637]])

# %%
# Create a DataFrame called with the scaled data
# The column names should match those referenced in the StandardScaler step
df_stocks_scaled = pd.DataFrame(
    stock_data_scaled,
    columns=["MeanOpen", "MeanHigh", "MeanLow", "MeanClose", "MeanVolume", "MeanPercentReturn"]
)

# Create a Ticker column in the df_stocks_scaled DataFrame
# using the index of the original df_stocks DataFrame
df_stocks_scaled["Ticker"] = df_stocks.index

# Set the newly created Ticker column as index of the df_stocks_scaled DataFrame
df_stocks_scaled = df_stocks_scaled.set_index("Ticker")

# Review the DataFrame
df_stocks_scaled.head()
# Out:
#         MeanOpen  MeanHigh   MeanLow  MeanClose  MeanVolume  MeanPercentReturn
# Ticker
# AA     -1.158886 -1.153217 -1.159624  -1.153417    0.103184          -1.610917
# AXP    -0.261157 -0.254393 -0.265739  -0.258185   -0.539199          -0.919042
# BA      0.575177  0.580564  0.564695   0.578916   -0.615824          -0.329342
# BAC    -1.229631 -1.224851 -1.230018  -1.225585    4.361945          -1.960402
# CAT     1.494216  1.505195  1.467062   1.500534   -0.586091          -0.800586

# %%
# Encode the Sector column
sector_encoded_df = pd.get_dummies(df_stocks["Sector"])

# Review the DataFrame
sector_encoded_df.head()
# Out:
#         Communication  Consumer Discretionary  Consumer Staples  Energy  \
# Ticker
# AA                  0                       0                 0       0
# AXP                 0                       0                 0       0
# BA                  0                       0                 0       0
# BAC                 0                       0                 0       0
# CAT                 0                       0                 0       0
#
#         Financials  Health Care  Industrials  Information Technology
# Ticker
# AA               0            0            1                       0
# AXP              1            0            0                       0
# BA               0            0            1                       0
# BAC              1            0            0                       0
# CAT              0            0            1                       0

# %%
# Concatenate the Sector encoded data with the scaled data DataFrame
df_stocks_scaled = pd.concat([df_stocks_scaled, sector_encoded_df], axis=1)

# Display the concatenated DataFrame
df_stocks_scaled.head()
# Out:
#         MeanOpen  MeanHigh   MeanLow  MeanClose  MeanVolume  \
# Ticker
# AA     -1.158886 -1.153217 -1.159624  -1.153417    0.103184
# AXP    -0.261157 -0.254393 -0.265739  -0.258185   -0.539199
# BA      0.575177  0.580564  0.564695   0.578916   -0.615824
# BAC    -1.229631 -1.224851 -1.230018  -1.225585    4.361945
# CAT     1.494216  1.505195  1.467062   1.500534   -0.586091
#
#         MeanPercentReturn  Communication  Consumer Discretionary  \
# Ticker
# AA              -1.610917              0                       0
# AXP             -0.919042              0                       0
# BA              -0.329342              0                       0
# BAC             -1.960402              0                       0
# CAT             -0.800586              0                       0
#
#         Consumer Staples  Energy  Financials  Health Care  Industrials  \
# Ticker
# AA                     0       0           0            0            1
# AXP                    0       0           1            0            0
# BA                     0       0           0            0            1
# BAC                    0       0           1            0            0
# CAT                    0       0           0            0            1
#
#         Information Technology
# Ticker
# AA                           0
# AXP                          0
# BA                           0
# BAC                          0
# CAT                          0

# %%
# Initialize the K-Means model with n_clusters=3,  n_init='auto', and random_state=1
model = KMeans(n_clusters=3, n_init='auto', random_state=1)

# Fit the model for the df_stocks_scaled DataFrame
model.fit(df_stocks_scaled)
# Out:
# KMeans(n_clusters=3, n_init='auto', random_state=1)

# %%
# Predict the model segments (clusters)
stock_clusters = model.predict(df_stocks_scaled)

# View the stock segments
print(stock_clusters)
# Out:
# [0 1 1 0 2 0 2 1 1 0 1 1 2 0 1 1 1 1 1 2 1 0 0 1 1 1 2 1 1 2]

# %%
# Create a copy of the concatenated DataFrame
df_stocks_scaled_predictions = df_stocks_scaled.copy()

# Create a new column in the copy of the concatenated DataFrame with the predicted clusters
df_stocks_scaled_predictions["StockCluster"] = stock_clusters

# Review the DataFrame
df_stocks_scaled_predictions
# Out:
#         MeanOpen  MeanHigh   MeanLow  MeanClose  MeanVolume  \
# Ticker
# AA     -1.158886 -1.153217 -1.159624  -1.153417    0.103184
# AXP    -0.261157 -0.254393 -0.265739  -0.258185   -0.539199
# BA      0.575177  0.580564  0.564695   0.578916   -0.615824
# BAC    -1.229631 -1.224851 -1.230018  -1.225585    4.361945
# CAT     1.494216  1.505195  1.467062   1.500534   -0.586091
# CSCO   -1.057671 -1.057730 -1.061867  -1.063041    1.379066
# CVX     1.415534  1.427278  1.425949   1.433089   -0.522031
# DD     -0.025298 -0.021919 -0.032543  -0.017114   -0.578096
# DIS    -0.376383 -0.365547 -0.372005  -0.361675   -0.461793
# GE     -1.046750 -1.043496 -1.045849  -1.041325    1.094627
# HD     -0.514516 -0.511710 -0.514764  -0.513506   -0.487168
# HPQ    -0.253326 -0.239221 -0.261282  -0.253357   -0.185330
# IBM     3.355944  3.364076  3.365797   3.362322   -0.615529
# INTC   -1.008501 -1.008591 -1.007978  -1.006705    0.946280
# JNJ     0.261036  0.240612  0.268642   0.244619   -0.441837
# JPM    -0.240488 -0.233174 -0.243400  -0.233857    0.210701
# KO      0.347229  0.339514  0.353784   0.338425   -0.515220
# KRFT   -0.689965 -0.695124 -0.685129  -0.689481   -0.495311
# MCD     0.712271  0.697714  0.710479   0.693383   -0.528170
# MMM     1.179248  1.171916  1.178896   1.170802   -0.674237
# MRK    -0.612428 -0.617468 -0.615114  -0.622431   -0.218149
# MSFT   -0.819867 -0.819781 -0.815841  -0.824213    1.011194
# PFE    -1.084493 -1.079288 -1.076697  -1.073095    0.793262
# PG      0.348108  0.326141  0.347841   0.329611   -0.455504
# T      -0.779487 -0.784537 -0.779726  -0.781835    0.070923
# TRV     0.143919  0.145073  0.149599   0.145351   -0.657926
# UTX     0.923279  0.909099  0.924982   0.918279   -0.666964
# VZ     -0.536250 -0.538221 -0.536914  -0.536674   -0.192239
# WMT     0.039374  0.035092  0.048304   0.034288   -0.389628
# XOM     0.899760  0.905997  0.898456   0.905877   -0.144935
#
#         MeanPercentReturn  Communication  Consumer Discretionary  \
# Ticker
# AA              -1.610917              0                       0
# AXP             -0.919042              0                       0
# BA              -0.329342              0                       0
# BAC             -1.960402              0                       0
# CAT             -0.800586              0                       0
# CSCO            -1.203150              0                       0
# CVX              0.141288              0                       0
# DD               0.278991              0                       0
# DIS              0.847408              1                       0
# GE               0.011832              0                       0
# HD              -0.043703              0                       1
# HPQ             -1.557889              0                       0
# IBM             -0.783740              0                       0
# INTC             0.489862              0                       0
# JNJ              0.666578              0                       0
# JPM             -0.457926              0                       0
# KO               0.137935              0                       0
# KRFT             0.738044              0                       0
# MCD              0.377955              0                       1
# MMM             -0.259803              0                       0
# MRK              1.405837              0                       0
# MSFT            -0.312777              0                       0
# PFE              1.113950              0                       0
# PG               0.406391              0                       0
# T                2.593634              1                       0
# TRV             -0.147167              0                       0
# UTX             -0.437765              1                       0
# VZ               2.090845              1                       0
# WMT             -0.029228              0                       0
# XOM             -0.447110              0                       0
#
#         Consumer Staples  Energy  Financials  Health Care  Industrials  \
# Ticker
# AA                     0       0           0            0            1
# AXP                    0       0           1            0            0
# BA                     0       0           0            0            1
# BAC                    0       0           1            0            0
# CAT                    0       0           0            0            1
# CSCO                   0       0           0            0            0
# CVX                    0       1           0            0            0
# DD                     0       0           0            0            1
# DIS                    0       0           0            0            0
# GE                     0       0           0            0            1
# HD                     0       0           0            0            0
# HPQ                    0       0           0            0            0
# IBM                    0       0           0            0            0
# INTC                   0       0           0            0            0
# JNJ                    0       0           0            1            0
# JPM                    0       0           1            0            0
# KO                     1       0           0            0            0
# KRFT                   1       0           0            0            0
# MCD                    0       0           0            0            0
# MMM                    0       0           0            0            1
# MRK                    0       0           0            1            0
# MSFT                   0       0           0            0            0
# PFE                    0       0           0            1            0
# PG                     1       0           0            0            0
# T                      0       0           0            0            0
# TRV                    0       0           1            0            0
# UTX                    0       0           0            0            0
# VZ                     0       0           0            0            0
# WMT                    1       0           0            0            0
# XOM                    0       1           0            0            0
#
#         Information Technology  StockCluster
# Ticker
# AA                           0             0
# AXP                          0             1
# BA                           0             1
# BAC                          0             0
# CAT                          0             2
# CSCO                         1             0
# CVX                          0             2
# DD                           0             1
# DIS                          0             1
# GE                           0             0
# HD                           0             1
# HPQ                          1             1
# IBM                          1             2
# INTC                         1             0
# JNJ                          0             1
# JPM                          0             1
# KO                           0             1
# KRFT                         0             1
# MCD                          0             1
# MMM                          0             2
# MRK                          0             1
# MSFT                         1             0
# PFE                          0             0
# PG                           0             1
# T                            0             1
# TRV                          0             1
# UTX                          0             2
# VZ                           0             1
# WMT                          0             1
# XOM                          0             2

# %%
# Import the data
import pandas as pd

# Create a Dataframe for the data
# Out:
#    age           job   marital  education default  balance housing loan  \
# 0   83       retired  divorced    primary      no        0      no   no
# 1   32    technician   married  secondary      no     1242     yes   no
# 2   38   blue-collar    single  secondary      no       68      no   no
# 3   30      services    single  secondary      no      677     yes   no
# 4   66       retired   married    primary      no     2173      no   no
# 5   43    technician    single  secondary      no        0     yes   no
# 6   44  entrepreneur  divorced   tertiary      no    20179     yes  yes
# 7   35     housemaid  divorced    primary      no     1465      no   no
# 8   39   blue-collar    single  secondary      no        0     yes   no
# 9   61    management    single   tertiary      no        2      no   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome    y
# 0  telephone   31   may       664         1   77.0         3  success   no
# ...

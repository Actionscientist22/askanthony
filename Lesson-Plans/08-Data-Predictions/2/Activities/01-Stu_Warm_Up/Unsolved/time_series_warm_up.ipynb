# %%
# Import the required libraries and dependencies
import pandas as pd

# %%
# Read csv file as DataFrame, with datetime index as the column date
data_path = "../Resources/bitcoin_hourly.csv"
df = pd.read_csv(
    data_path,
    infer_datetime_format=True,
    parse_dates=True,
    index_col='date'
)

# Preview the dataset
df.head()
# Out:
#                        close     volume
# date
# 2017-08-17 05:00:00  4315.32  23.234916
# 2017-08-17 06:00:00  4324.35   7.229691
# 2017-08-17 07:00:00  4349.99   4.443249
# 2017-08-17 08:00:00  4360.69   0.972807
# 2017-08-17 09:00:00  4444.00  10.763623

# %%
# Plot volume to get a sense of what's typical volume for the cryptocurrency.
# Out:
# <Axes: xlabel='date'>

# %%
# Use groupby and the weekofyear function on the datetime index to create a bar plot of the data
# Out:
# /var/folders/9y/xk65y3897k7gncdq0_fzx4fx7vp8rq/T/ipykernel_83769/759721426.py:2: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df.groupby(df.index.weekofyear).mean().plot(kind='bar')
# <Axes: xlabel='date'>

# %%
# Plot hourly trends in prices and volume for the cryptocurrency
# Out:
# <Axes: xlabel='date'>

# %%
# Slice to one day before and after Jan 29, 2021
# Out:
# <Axes: xlabel='date'>

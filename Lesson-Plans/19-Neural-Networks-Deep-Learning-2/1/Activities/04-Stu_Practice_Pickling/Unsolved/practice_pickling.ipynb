# %%
# Import dependencies
import requests
from PIL import Image
import pandas as pd

# %%
path = "https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/csvs/fungi_files.csv"

# Read the csv file in and view the first few rows
filenames_df = pd.read_csv(path)
filenames_df.head()
# Out:
#             name
# 0  H1_103a_3.jpg
# 1   H1_38b_2.jpg
# 2   H2_8f_14.jpg
# 3   H1_99a_2.jpg
# 4   H2_49c_2.jpg

# %%
# Build a list of images using a for loop

# Define the base_url
base_url = "https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/"

# Create an empty list for the urls


# Loop through the DataFrame and build and append the full image urls
# Out:
# ['https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_103a_3.jpg',
#  'https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_38b_2.jpg',
#  'https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H2_8f_14.jpg',
#  'https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_99a_2.jpg',
#  'https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H2_49c_2.jpg']

# %%
# Check the number of urls
# Out:
# 250

# %%
# Create and empty list for images

# Loop through ONLY THE FIRST 20 image_urls to open and append each image


    # Print a statement to show progress
    
    # Use requests.get along with the stream parameter and raw attribute

    # Append each img to the imgs list

# View the first image to confirm
# Out:
# 0/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_103a_3.jpg
# 1/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_38b_2.jpg
# 2/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H2_8f_14.jpg
# 3/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_99a_2.jpg
# 4/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H2_49c_2.jpg
# 5/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_65c_10.jpg
# 6/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H2_23a_3.jpg
# 7/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H2_33b_9.jpg
# 8/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_43b_9.jpg
# 9/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_96c_20.jpg
# 10/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_104c_5.jpg
# 11/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_96a_5.jpg
# 12/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_1d_2.jpg
# 13/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_100a_4.jpg
# 14/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_32a_7.jpg
# 15/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_52b_16.jpg
# 16/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_113a_9.jpg
# 17/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_6b_6.jpg
# 18/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H2_30d_2.jpg
# 19/20: Attempting to import https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_1/datasets/fungi_images/H1_99c_5.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>

# %%
# Import the modules
from google.colab import drive
import pickle

drive.mount('/content/drive/')

# Open a new file named 'fungi.pkl' with write permission


    # Use pickle.dump to store the list of images
# Out:
# Mounted at /content/drive/

# %%
# Load the images from the pkl file
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>

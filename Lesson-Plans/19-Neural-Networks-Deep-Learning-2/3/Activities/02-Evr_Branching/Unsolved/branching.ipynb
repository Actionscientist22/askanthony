# %%
from tensorflow.keras import layers, models, Model
import numpy as np
import pandas as pd

# %%
# Import the data
path = 'https://static.bc-edx.com/ai/ail-v-1-0/m19/lesson_3/datasets/wine_quality.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.2              0.39         0.63            11.0      0.044
# 1            6.9              0.63         0.02             1.9      0.078
# 2            6.9              0.30         0.33             4.1      0.035
# 3            7.3              0.42         0.38             6.8      0.045
# 4            6.9              0.18         0.38             8.1      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 55.0                 156.0  0.99740  3.09       0.44
# 1                 18.0                  30.0  0.99712  3.40       0.75
# 2                 26.0                 155.0  0.99250  3.25       0.79
# 3                 29.0                 122.0  0.99250  3.19       0.37
# 4                 44.0                 176.0  0.99580  3.30       0.54
#
#    alcohol quality  color
# 0      8.7      ok  white
# 1      9.8      ok    red
# 2     12.3    good  white
# 3     12.6    good  white
# 4      9.8      ok  white

# %% [markdown]
# We have two choices; should the y columns of quality and color all be predicted in a single layer? It might be easier to separate these into two layers, both having the sigmoid activation function. To start, lets preprocess these layers using labelencoder and onehotencoder.

# %%
# Preprocess y
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Preprocess "quality" column (one-hot encoding)


# Preprocess "color" column (label encoding for binary; one-hot encoding for multiple categories)


# Concatenate the encoded columns to the original DataFrame


# Drop the original "quality" and "color" columns
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.2              0.39         0.63            11.0      0.044
# 1            6.9              0.63         0.02             1.9      0.078
# 2            6.9              0.30         0.33             4.1      0.035
# 3            7.3              0.42         0.38             6.8      0.045
# 4            6.9              0.18         0.38             8.1      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 55.0                 156.0  0.99740  3.09       0.44
# 1                 18.0                  30.0  0.99712  3.40       0.75
# 2                 26.0                 155.0  0.99250  3.25       0.79
# 3                 29.0                 122.0  0.99250  3.19       0.37
# 4                 44.0                 176.0  0.99580  3.30       0.54
#
#    alcohol  color_encoded  quality_bad  quality_good  quality_ok
# 0      8.7              1          0.0           0.0         1.0
# 1      9.8              0          0.0           0.0         1.0
# 2     12.3              1          0.0           1.0         0.0
# 3     12.6              1          0.0           1.0         0.0
# 4      9.8              1          0.0           0.0         1.0

# %%
# Split data into X and two separate y variables



# Split data into training and testing sets
from sklearn.model_selection import train_test_split

# %% [markdown]
# Now that the data is processed, start by creating the shared portion of the model. We start with the input layer, but note that because we are note using the "sequential" model from keras, we must specify where each new layer attaches to the model. We do this by placing the name of the preceding layer in parentheses at the end of the line creating the new layer.
#
# Note how shared_layer1 is created as a Dense layer, and then (input_layer) specifies that shared_layer1 will come directly after the input_layer. In the following line, shared_layer2 is created to follow shared_layer1.

# %%
# Create the shared layers of the model

# Input layer

# Shared hidden layers

# %% [markdown]
# So far, we've created a sequential set on layers, one following the other. Now we will create two branches for our two output layers. To do this, we create two layers and specify the same "preceding layer" for each. Note how both the quality_output layer and the color_output layer connect to the model via shared_layer2.
#
# When creating these layers, we determine that sigmoid is best for quality and for color. That said, there are arguments to be made for either!

# %%
# Branch for quality prediction

# Branch for color prediction

# %% [markdown]
# Now we can pull the model together. We only need to specify the input and output layers and Keras will infer the rest. To compile the model, we can specify unique metrics and loss functions for each output layer, but for this dataset we have chosen 'binary_crossentropy' as the loss function and 'accuracy' as the metric for both output layers.

# %%
# Create the model

# Compile the model


# Display the model summary
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_features (InputLayer  [(None, 11)]                 0         []
#  )
#
#  dense (Dense)               (None, 64)                   768       ['input_features[0][0]']
#
#  dense_1 (Dense)             (None, 32)                   2080      ['dense[0][0]']
#
#  quality_output (Dense)      (None, 3)                    99        ['dense_1[0][0]']
#
#  color_output (Dense)        (None, 1)                    33        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 2980 (11.64 KB)
# Trainable params: 2980 (11.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# To fit the model to the data, we specify X_train as normal, but pass a dictionary for the y_data.

# %%
# Fit the model
# Out:
# Epoch 1/10
# 163/163 [==============================] - 13s 21ms/step - loss: 2.4630 - quality_output_loss: 1.0841 - color_output_loss: 1.3789 - quality_output_accuracy: 0.7223 - color_output_accuracy: 0.8480 - val_loss: 0.9039 - val_quality_output_loss: 0.6756 - val_color_output_loss: 0.2283 - val_quality_output_accuracy: 0.7469 - val_color_output_accuracy: 0.9300
# Epoch 2/10
# 163/163 [==============================] - 1s 4ms/step - loss: 0.8464 - quality_output_loss: 0.6565 - color_output_loss: 0.1898 - quality_output_accuracy: 0.7635 - color_output_accuracy: 0.9363 - val_loss: 0.8730 - val_quality_output_loss: 0.6679 - val_color_output_loss: 0.2051 - val_quality_output_accuracy: 0.7469 - val_color_output_accuracy: 0.9315
# Epoch 3/10
# 163/163 [==============================] - 1s 4ms/step - loss: 0.8021 - quality_output_loss: 0.6321 - color_output_loss: 0.1700 - quality_output_accuracy: 0.7699 - color_output_accuracy: 0.9392 - val_loss: 0.8321 - val_quality_output_loss: 0.6291 - val_color_output_loss: 0.2030 - val_quality_output_accuracy: 0.7485 - val_color_output_accuracy: 0.9308
# Epoch 4/10
# 163/163 [==============================] - 1s 4ms/step - loss: 0.7822 - quality_output_loss: 0.6209 - color_output_loss: 0.1613 - quality_output_accuracy: 0.7658 - color_output_accuracy: 0.9434 - val_loss: 0.8264 - val_quality_output_loss: 0.6421 - val_color_output_loss: 0.1843 - val_quality_output_accuracy: 0.7469 - val_color_output_accuracy: 0.9369
# Epoch 5/10
# 163/163 [==============================] - 1s 3ms/step - loss: 0.7561 - quality_output_loss: 0.6085 - color_output_loss: 0.1476 - quality_output_accuracy: 0.7689 - color_output_accuracy: 0.9486 - val_loss: 0.9376 - val_quality_output_loss: 0.7419 - val_color_output_loss: 0.1957 - val_quality_output_accuracy: 0.6162 - val_color_output_accuracy: 0.9238
# Epoch 6/10
# 163/163 [==============================] - 1s 3ms/step - loss: 0.7555 - quality_output_loss: 0.6140 - color_output_loss: 0.1415 - quality_output_accuracy: 0.7566 - color_output_accuracy: 0.9498 - val_loss: 0.8608 - val_quality_output_loss: 0.6956 - val_color_output_loss: 0.1652 - val_quality_output_accuracy: 0.7469 - val_color_output_accuracy: 0.9423
# Epoch 7/10
# 163/163 [==============================] - 1s 4ms/step - loss: 0.7605 - quality_output_loss: 0.6267 - color_output_loss: 0.1337 - quality_output_accuracy: 0.7566 - color_output_accuracy: 0.9529 - val_loss: 0.7751 - val_quality_output_loss: 0.6122 - val_color_output_loss: 0.1629 - val_quality_output_accuracy: 0.7492 - val_color_output_accuracy: 0.9438
# Epoch 8/10
# 163/163 [==============================] - 0s 3ms/step - loss: 0.7219 - quality_output_loss: 0.5930 - color_output_loss: 0.1288 - quality_output_accuracy: 0.7729 - color_output_accuracy: 0.9557 - val_loss: 0.7869 - val_quality_output_loss: 0.6393 - val_color_output_loss: 0.1477 - val_quality_output_accuracy: 0.7231 - val_color_output_accuracy: 0.9485
# Epoch 9/10
# 163/163 [==============================] - 1s 5ms/step - loss: 0.7143 - quality_output_loss: 0.5980 - color_output_loss: 0.1164 - quality_output_accuracy: 0.7676 - color_output_accuracy: 0.9604 - val_loss: 0.7549 - val_quality_output_loss: 0.6178 - val_color_output_loss: 0.1371 - val_quality_output_accuracy: 0.7423 - val_color_output_accuracy: 0.9531
# Epoch 10/10
# 163/163 [==============================] - 1s 5ms/step - loss: 0.6809 - quality_output_loss: 0.5698 - color_output_loss: 0.1111 - quality_output_accuracy: 0.7729 - color_output_accuracy: 0.9611 - val_loss: 0.7519 - val_quality_output_loss: 0.6117 - val_color_output_loss: 0.1402 - val_quality_output_accuracy: 0.7562 - val_color_output_accuracy: 0.9515

# %%
# Evaluate the model with the testing data
# Out:
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6919 - quality_output_loss: 0.5785 - color_output_loss: 0.1134 - quality_output_accuracy: 0.7717 - color_output_accuracy: 0.9569
# [0.6919273734092712,
#  0.5785049796104431,
#  0.11342228204011917,
#  0.7716923356056213,
#  0.9569230675697327]

# %%
# Print quality and color accuracy
# Out:
# Quality Accuracy: 0.7716923356056213
# Color Accuracy: 0.9569230675697327

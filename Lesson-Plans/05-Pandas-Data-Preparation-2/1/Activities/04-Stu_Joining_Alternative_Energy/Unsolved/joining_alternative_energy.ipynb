# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path

# %%
# Import the 2016 - 2020 alternative fuel stations data. 

# Read in data setting the `index_col` to the Fuel Type.

# %%
# Display the 2016 data.
# Out:
#            Number_Stations  Year
# Fuel_Type
# 85E                   3095  2016
# Biodiesel              716  2016
# CNG                   1730  2016
# Electric             45124  2016
# Hydrogen                58  2016
# LNG                    140  2016
# Propane               3654  2016

# %%
# Display the 2017 data.
# Out:
#            Number_Stations  Year
# Fuel_Type
# 85E                   3379  2017
# Biodiesel              704  2017
# CNG                   1682  2017
# Electric             53117  2017
# Hydrogen                63  2017
# LNG                    137  2017
# Propane               3510  2017

# %%
# Display the 2018 data.
# Out:
#            Number_Stations  Year
# Fuel_Type
# 85E                   3661  2018
# Biodiesel              672  2018
# CNG                   1586  2018
# Electric             69161  2018
# Hydrogen                62  2018
# LNG                    121  2018
# Propane               3302  2018

# %%
# Display the 2019 data.
# Out:
#            Number_Stations  Year
# Fuel_Type
# 85E                   3794  2019
# Biodiesel              607  2019
# CNG                   1574  2019
# Electric             89433  2019
# Hydrogen                62  2019
# LNG                    114  2019
# Propane               3118  2019

# %%
# Display the 2020 data.
# Out:
#            Number_Stations  Year
# Fuel_Type
# 85E                   3717  2020
# Biodiesel              301  2020
# CNG                    863  2020
# Electric             96626  2020
# Hydrogen                46  2020
# LNG                     58  2020
# Propane               2671  2020

# %% [markdown]
# ### Join 2016 to 2017.

# %%
# Join the 2016 and 2017 data where the left suffix is 2016 and right suffix is 2017.
# Out:
#            Number_Stations_2016  Year_2016  Number_Stations_2017  Year_2017
# Fuel_Type
# 85E                        3095       2016                  3379       2017
# Biodiesel                   716       2016                   704       2017
# CNG                        1730       2016                  1682       2017
# Electric                  45124       2016                 53117       2017
# Hydrogen                     58       2016                    63       2017
# LNG                         140       2016                   137       2017
# Propane                    3654       2016                  3510       2017

# %% [markdown]
# ### Join 2018, 2019, and 2020 data to the 2016 and 2017 data.

# %%
# Create a list to hold the 2018, 2019, and 2020 DataFrames and add "_2018", "_2019" and, "_2020" 
# suffixes to the 2018, 2019, and 2020 DataFrames using the `add_suffix()` method.

# Join the 2016-2017 data with the 2018-2020 data.
# Out:
#            Number_Stations_2016  Year_2016  Number_Stations_2017  Year_2017  \
# Fuel_Type
# 85E                        3095       2016                  3379       2017
# Biodiesel                   716       2016                   704       2017
# CNG                        1730       2016                  1682       2017
# Electric                  45124       2016                 53117       2017
# Hydrogen                     58       2016                    63       2017
# LNG                         140       2016                   137       2017
# Propane                    3654       2016                  3510       2017
#
#            Number_Stations_2018  Year_2018  Number_Stations_2019  Year_2019  \
# Fuel_Type
# 85E                        3661       2018                  3794       2019
# Biodiesel                   672       2018                   607       2019
# CNG                        1586       2018                  1574       2019
# Electric                  69161       2018                 89433       2019
# Hydrogen                     62       2018                    62       2019
# LNG                         121       2018                   114       2019
# Propane                    3302       2018                  3118       2019
#
#            Number_Stations_2020  Year_2020
# Fuel_Type
# 85E                        3717       2020
# Biodiesel                   301       2020
# CNG                         863       2020
# Electric                  96626       2020
# Hydrogen                     46       2020
# LNG                          58       2020
# Propane                    2671       2020

# %% [markdown]
# ### Drop all the columns with "year_" and sort the DataFrame.

# %%
# Get the column names
# Out:
# Index(['Number_Stations_2016', 'Year_2016', 'Number_Stations_2017',
#        'Year_2017', 'Number_Stations_2018', 'Year_2018',
#        'Number_Stations_2019', 'Year_2019', 'Number_Stations_2020',
#        'Year_2020'],
#       dtype='object')

# %%
# Drop the columns with the "year_<year>".
# Out:
#            Number_Stations_2016  Number_Stations_2017  Number_Stations_2018  \
# Fuel_Type
# 85E                        3095                  3379                  3661
# Biodiesel                   716                   704                   672
# CNG                        1730                  1682                  1586
# Electric                  45124                 53117                 69161
# Hydrogen                     58                    63                    62
# LNG                         140                   137                   121
# Propane                    3654                  3510                  3302
#
#            Number_Stations_2019  Number_Stations_2020
# Fuel_Type
# 85E                        3794                  3717
# Biodiesel                   607                   301
# CNG                        1574                   863
# Electric                  89433                 96626
# Hydrogen                     62                    46
# LNG                         114                    58
# Propane                    3118                  2671

# %%
# Sort the DataFrame on all the columns in ascending order.  



# Display the sorted DataFrame.
# Out:
#            Number_Stations_2016  Number_Stations_2017  Number_Stations_2018  \
# Fuel_Type
# Electric                  45124                 53117                 69161
# Propane                    3654                  3510                  3302
# 85E                        3095                  3379                  3661
# CNG                        1730                  1682                  1586
# Biodiesel                   716                   704                   672
# LNG                         140                   137                   121
# Hydrogen                     58                    63                    62
#
#            Number_Stations_2019  Number_Stations_2020
# Fuel_Type
# Electric                  89433                 96626
# Propane                    3118                  2671
# 85E                        3794                  3717
# CNG                        1574                   863
# Biodiesel                   607                   301
# LNG                         114                    58
# Hydrogen                     62                    46

# %%
# Import Dependencies
import pandas as pd

# %%
# Read file into DataFrame
book_sales_df = pd.read_csv('Resources/book_sales.csv')
book_sales_df.head(20)
# Out:
#                                             book_name date_ending  total_sales
# 0                                          The Hobbit     8/31/23          150
# 1   The Fellowship of the Ring (The Lord of the Ri...     8/31/23           80
# 2      The Two Towers (The Lord of the Rings, Part 2)     8/31/23          100
# 3   The Return of the King (The Lord of the Rings,...     8/31/23          100
# 4                                          Foundation     8/31/23           60
# 5                               Foundation and Empire     8/31/23           40
# 6                                   Second Foundation     8/31/23           35
# 7                                   Foundation's Edge     8/31/23           20
# 8                                Foundation and Earth     8/31/23            0
# 9                                          The Hobbit     9/30/23          100
# 10  The Fellowship of the Ring (The Lord of the Ri...     9/30/23          150
# 11     The Two Towers (The Lord of the Rings, Part 2)     9/30/23           75
# 12  The Return of the King (The Lord of the Rings,...     9/30/23          125
# 13                                         Foundation     9/30/23          100
# 14                              Foundation and Empire     9/30/23           50
# 15                                  Second Foundation     9/30/23           40
# 16                                  Foundation's Edge     9/30/23           30
# 17                               Foundation and Earth     9/30/23           20
# 18                                         The Hobbit    10/31/23          200
# 19  The Fellowship of the Ring (The Lord of the Ri...    10/31/23          125

# %%
# Show the unique values in the book_name column.
book_sales_df["book_name"].unique()
# Out:
# array(['The Hobbit',
#        'The Fellowship of the Ring (The Lord of the Rings, Part 1)',
#        'The Two Towers (The Lord of the Rings, Part 2)',
#        'The Return of the King (The Lord of the Rings, Part 3)',
#        'Foundation', 'Foundation and Empire', 'Second Foundation',
#        "Foundation's Edge", 'Foundation and Earth'], dtype=object)

# %%
# Show the unique values in the date_ending column.
book_sales_df["date_ending"].unique()
# Out:
# array(['8/31/23', '9/30/23', '10/31/23', '11/30/23', '12/31/23'],
#       dtype=object)

# %% [markdown]
# ### Using the `pivot()` function.
# ---
# `pd.pivot(data, columns, index=<a column>, values=<a column>` or `df.pivot(columns, index=<a column>, values=<a column>`

# %%
#  Pivot on the date_ending with the book_name as the index, and pass the "total_sales" as the values.
pivot_date_short_form = pd.pivot(book_sales_df, columns="date_ending",index="book_name",values="total_sales" )
# Show the table.
pivot_date_short_form
# Out:
# date_ending                                         10/31/23  11/30/23  \
# book_name
# Foundation                                                75        50
# Foundation and Earth                                      25        30
# Foundation and Empire                                     75        60
# Foundation's Edge                                         25        30
# Second Foundation                                         50       100
# The Fellowship of the Ring (The Lord of the Rin...       125       100
# The Hobbit                                               200       200
# The Return of the King (The Lord of the Rings, ...       200        50
# The Two Towers (The Lord of the Rings, Part 2)           225       100
#
# date_ending                                         12/31/23  8/31/23  9/30/23
# book_name
# Foundation                                               125       60      100
# Foundation and Earth                                      20        0       20
# Foundation and Empire                                     75       40       50
# Foundation's Edge                                         30       20       30
# Second Foundation                                         50       35       40
# The Fellowship of the Ring (The Lord of the Rin...       175       80      150
# The Hobbit                                               250      150      100
# The Return of the King (The Lord of the Rings, ...       200      100      125
# The Two Towers (The Lord of the Rings, Part 2)           150      100       75

# %%
# Reorder columns
pivot_date_short_form.iloc[:,[3,4,0,1,2]]
# Out:
# date_ending                                         8/31/23  9/30/23  \
# book_name
# Foundation                                               60      100
# Foundation and Earth                                      0       20
# Foundation and Empire                                    40       50
# Foundation's Edge                                        20       30
# Second Foundation                                        35       40
# The Fellowship of the Ring (The Lord of the Rin...       80      150
# The Hobbit                                              150      100
# The Return of the King (The Lord of the Rings, ...      100      125
# The Two Towers (The Lord of the Rings, Part 2)          100       75
#
# date_ending                                         10/31/23  11/30/23  \
# book_name
# Foundation                                                75        50
# Foundation and Earth                                      25        30
# Foundation and Empire                                     75        60
# Foundation's Edge                                         25        30
# Second Foundation                                         50       100
# The Fellowship of the Ring (The Lord of the Rin...       125       100
# The Hobbit                                               200       200
# The Return of the King (The Lord of the Rings, ...       200        50
# The Two Towers (The Lord of the Rings, Part 2)           225       100
#
# date_ending                                         12/31/23
# book_name
# Foundation                                               125
# Foundation and Earth                                      20
# Foundation and Empire                                     75
# Foundation's Edge                                         30
# Second Foundation                                         50
# The Fellowship of the Ring (The Lord of the Rin...       175
# The Hobbit                                               250
# The Return of the King (The Lord of the Rings, ...       200
# The Two Towers (The Lord of the Rings, Part 2)           150

# %%
#  Pivot on the book_name with the date_ending as the index, and pass the "total_sales" as the values.
pivot_books_long_form = pd.pivot(book_sales_df, columns="book_name",index="date_ending",values="total_sales" )
pivot_books_long_form
# Out:
# book_name    Foundation  Foundation and Earth  Foundation and Empire  \
# date_ending
# 10/31/23             75                    25                     75
# 11/30/23             50                    30                     60
# 12/31/23            125                    20                     75
# 8/31/23              60                     0                     40
# 9/30/23             100                    20                     50
#
# book_name    Foundation's Edge  Second Foundation  \
# date_ending
# 10/31/23                    25                 50
# 11/30/23                    30                100
# 12/31/23                    30                 50
# 8/31/23                     20                 35
# 9/30/23                     30                 40
#
# book_name    The Fellowship of the Ring (The Lord of the Rings, Part 1)  \
# date_ending
# 10/31/23                                                   125
# 11/30/23                                                   100
# 12/31/23                                                   175
# 8/31/23                                                     80
# 9/30/23                                                    150
#
# book_name    The Hobbit  \
# date_ending
# 10/31/23            200
# 11/30/23            200
# 12/31/23            250
# 8/31/23             150
# 9/30/23             100
#
# book_name    The Return of the King (The Lord of the Rings, Part 3)  \
# date_ending
# 10/31/23                                                   200
# 11/30/23                                                    50
# 12/31/23                                                   200
# 8/31/23                                                    100
# 9/30/23                                                    125
#
# book_name    The Two Towers (The Lord of the Rings, Part 2)
# date_ending
# 10/31/23                                                225
# 11/30/23                                                100
# 12/31/23                                                150
# 8/31/23                                                 100
# 9/30/23                                                  75

# %%
# We can't use sort_values to sort the index. We have to use `reindex`.  
# Get the index values to copy.
pivot_books_long_form.index
# Out:
# Index(['10/31/23', '11/30/23', '12/31/23', '8/31/23', '9/30/23'], dtype='object', name='date_ending')

# %%
# Reindex in monthly ascending order. 
pivot_books_long_form.reindex(['8/31/23', '9/30/23','10/31/23', '11/30/23', '12/31/23'])
# Out:
# book_name    Foundation  Foundation and Earth  Foundation and Empire  \
# date_ending
# 8/31/23              60                     0                     40
# 9/30/23             100                    20                     50
# 10/31/23             75                    25                     75
# 11/30/23             50                    30                     60
# 12/31/23            125                    20                     75
#
# book_name    Foundation's Edge  Second Foundation  \
# date_ending
# 8/31/23                     20                 35
# 9/30/23                     30                 40
# 10/31/23                    25                 50
# 11/30/23                    30                100
# 12/31/23                    30                 50
#
# book_name    The Fellowship of the Ring (The Lord of the Rings, Part 1)  \
# date_ending
# 8/31/23                                                     80
# 9/30/23                                                    150
# 10/31/23                                                   125
# 11/30/23                                                   100
# 12/31/23                                                   175
#
# book_name    The Hobbit  \
# date_ending
# 8/31/23             150
# 9/30/23             100
# 10/31/23            200
# 11/30/23            200
# 12/31/23            250
#
# book_name    The Return of the King (The Lord of the Rings, Part 3)  \
# date_ending
# 8/31/23                                                    100
# 9/30/23                                                    125
# 10/31/23                                                   200
# 11/30/23                                                    50
# 12/31/23                                                   200
#
# book_name    The Two Towers (The Lord of the Rings, Part 2)
# date_ending
# 8/31/23                                                 100
# 9/30/23                                                  75
# 10/31/23                                                225
# 11/30/23                                                100
# 12/31/23                                                150

# %% [markdown]
# ### Using the `pivot_table()` function.
# ---
#
# - `pd.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False, sort=True)`
# - `pivot_table()` performs the mean aggregation by defualt

# %%
# Using the `pivot_table()` function, get the total book sales for each book. 
# Make the columns the book title. 
pivot_table_books_sum = pd.pivot_table(book_sales_df, 
                                       values='total_sales',
                                       columns='book_name', 
                                       aggfunc='sum')

# Show the table.
pivot_table_books_sum
# Out:
# book_name    Foundation  Foundation and Earth  Foundation and Empire  \
# total_sales         410                    95                    300
#
# book_name    Foundation's Edge  Second Foundation  \
# total_sales                135                275
#
# book_name    The Fellowship of the Ring (The Lord of the Rings, Part 1)  \
# total_sales                                                630
#
# book_name    The Hobbit  \
# total_sales         900
#
# book_name    The Return of the King (The Lord of the Rings, Part 3)  \
# total_sales                                                675
#
# book_name    The Two Towers (The Lord of the Rings, Part 2)
# total_sales                                             650

# %%
# Using the `pivot_table()` function, get the average book sales for each book. 
# Make the columns the book title. 
pivot_table_books_avg = book_sales_df.pivot_table(values='total_sales',
                                                  columns='book_name',
                                                  aggfunc='mean')
# Show the table.
pivot_table_books_avg
# Out:
# book_name    Foundation  Foundation and Earth  Foundation and Empire  \
# total_sales          82                    19                     60
#
# book_name    Foundation's Edge  Second Foundation  \
# total_sales                 27                 55
#
# book_name    The Fellowship of the Ring (The Lord of the Rings, Part 1)  \
# total_sales                                                126
#
# book_name    The Hobbit  \
# total_sales         180
#
# book_name    The Return of the King (The Lord of the Rings, Part 3)  \
# total_sales                                                135
#
# book_name    The Two Towers (The Lord of the Rings, Part 2)
# total_sales                                             130

# %%
# Rename the index: "total_sales" to "Avg_Sales".
pivot_table_books_avg.rename(index={'total_sales': 'Avg_Sales'})
# Out:
# book_name  Foundation  Foundation and Earth  Foundation and Empire  \
# Avg_Sales          82                    19                     60
#
# book_name  Foundation's Edge  Second Foundation  \
# Avg_Sales                 27                 55
#
# book_name  The Fellowship of the Ring (The Lord of the Rings, Part 1)  \
# Avg_Sales                                                126
#
# book_name  The Hobbit  The Return of the King (The Lord of the Rings, Part 3)  \
# Avg_Sales         180                                                135
#
# book_name  The Two Towers (The Lord of the Rings, Part 2)
# Avg_Sales                                             130

# %% [markdown]
# ### Mutiple aggregations.

# %%
# Get the total and average book sales for each book. 
# Make the books the columns, and the mean and sum of the total sales under each book. 
avg_sum_books = pd.pivot_table(book_sales_df, 
                               values='total_sales',
                               columns='book_name',
                               aggfunc=('sum', 'mean'))
# Show the table
avg_sum_books
# Out:
# book_name  Foundation  Foundation and Earth  Foundation and Empire  \
# mean             82.0                  19.0                   60.0
# sum             410.0                  95.0                  300.0
#
# book_name  Foundation's Edge  Second Foundation  \
# mean                    27.0               55.0
# sum                    135.0              275.0
#
# book_name  The Fellowship of the Ring (The Lord of the Rings, Part 1)  \
# mean                                                   126.0
# sum                                                    630.0
#
# book_name  The Hobbit  The Return of the King (The Lord of the Rings, Part 3)  \
# mean            180.0                                              135.0
# sum             900.0                                              675.0
#
# book_name  The Two Towers (The Lord of the Rings, Part 2)
# mean                                                130.0
# sum                                                 650.0

# %%
# Using the pivot_table function get the average and the total of the book sales 
# for each date. Make the date the index and round to one decimal place. 
date_ending_pivot_table = book_sales_df.pivot_table(index="date_ending", 
                                             values="total_sales",
                                            aggfunc=('mean','sum')).round(1)
# Show the table
date_ending_pivot_table
# Out:
#               mean   sum
# date_ending
# 10/31/23     111.1  1000
# 11/30/23      80.0   720
# 12/31/23     119.4  1075
# 8/31/23       65.0   585
# 9/30/23       76.7   690

# %%
# Reindex in monthly ascending order. 
date_ending_pivot_table.reindex(['8/31/23', '9/30/23','10/31/23', '11/30/23', '12/31/23'])
# Out:
#               mean   sum
# date_ending
# 8/31/23       65.0   585
# 9/30/23       76.7   690
# 10/31/23     111.1  1000
# 11/30/23      80.0   720
# 12/31/23     119.4  1075

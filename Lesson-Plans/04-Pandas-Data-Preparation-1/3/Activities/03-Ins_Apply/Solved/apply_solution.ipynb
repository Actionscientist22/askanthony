# %%
import pandas as pd

# %%
# Import the data
file = '../Resources/donors2021.csv'
donors_df = pd.read_csv(file)
donors_df.head()
# Out:
#                                Name                      Employer  \
# 0                      CAREY, JAMES                  NOT EMPLOYED
# 1                    OBICI, SILVANA                   STONY BROOK
# 2                    MAISLIN, KAREN                       RETIRED
# 3  MCCLELLAND, CARTER AND STEPHANIE         UNION SQUARE ADVISORS
# 4                 MCCLUSKEY, MARTHA  STATE UNIVERSITY OF NEW YORK
#
#                      City State          Zip  Amount  Memo_CD
# 0               HOCKESSIN    DE  197071618.0     500      NaN
# 1  PORT JEFFERSON STATION    NY  117764286.0     250      NaN
# 2           WILLIAMSVILLE    NY      14221.0     250      NaN
# 3                NEW YORK    NY      10023.0    1000      NaN
# 4                 BUFFALO    NY      14214.0     250      NaN

# %%
# If 10% of every donation was fully matched by an 
# anonymous philanthropist, making a new column would be easy.

donors_df['Match Amount'] = donors_df['Amount'] * 0.1
donors_df.head()
# Out:
#                                Name                      Employer  \
# 0                      CAREY, JAMES                  NOT EMPLOYED
# 1                    OBICI, SILVANA                   STONY BROOK
# 2                    MAISLIN, KAREN                       RETIRED
# 3  MCCLELLAND, CARTER AND STEPHANIE         UNION SQUARE ADVISORS
# 4                 MCCLUSKEY, MARTHA  STATE UNIVERSITY OF NEW YORK
#
#                      City State          Zip  Amount  Memo_CD  Match Amount
# 0               HOCKESSIN    DE  197071618.0     500      NaN          50.0
# 1  PORT JEFFERSON STATION    NY  117764286.0     250      NaN          25.0
# 2           WILLIAMSVILLE    NY      14221.0     250      NaN          25.0
# 3                NEW YORK    NY      10023.0    1000      NaN         100.0
# 4                 BUFFALO    NY      14214.0     250      NaN          25.0

# %%
# What if the match percentage changed based on the amount donated?
# 10% on donations below $500, and 20% on donations of $500 or more.
# We need a new solution! A perfect opportunity for 'apply'.

# Define a function
def match_amount(amount):
    if amount < 500:
        return amount * 0.1
    return amount * 0.2

# "Apply" the function to the amount column
donors_df['Match Amount'] = donors_df['Amount'].apply(match_amount)
donors_df.head()
# Out:
#                                Name                      Employer  \
# 0                      CAREY, JAMES                  NOT EMPLOYED
# 1                    OBICI, SILVANA                   STONY BROOK
# 2                    MAISLIN, KAREN                       RETIRED
# 3  MCCLELLAND, CARTER AND STEPHANIE         UNION SQUARE ADVISORS
# 4                 MCCLUSKEY, MARTHA  STATE UNIVERSITY OF NEW YORK
#
#                      City State          Zip  Amount  Memo_CD  Match Amount
# 0               HOCKESSIN    DE  197071618.0     500      NaN         100.0
# 1  PORT JEFFERSON STATION    NY  117764286.0     250      NaN          25.0
# 2           WILLIAMSVILLE    NY      14221.0     250      NaN          25.0
# 3                NEW YORK    NY      10023.0    1000      NaN         200.0
# 4                 BUFFALO    NY      14214.0     250      NaN          25.0

# %%
# Apply can also use values from multiple columns by
# setting the axis argument to 1. Suppose the donor 
# was only matching donations from Delaware.

def match_amount(row):
    if (row['State'] != 'DE'):
        return 0
    if (row['Amount'] < 500):
        return row['Amount'] * 0.1
    return row['Amount'] * 0.2

# "Apply" the function to the DataFrame
donors_df['Match Amount'] = donors_df.apply(match_amount, axis = 1)
donors_df.head()
# Out:
#                                Name                      Employer  \
# 0                      CAREY, JAMES                  NOT EMPLOYED
# 1                    OBICI, SILVANA                   STONY BROOK
# 2                    MAISLIN, KAREN                       RETIRED
# 3  MCCLELLAND, CARTER AND STEPHANIE         UNION SQUARE ADVISORS
# 4                 MCCLUSKEY, MARTHA  STATE UNIVERSITY OF NEW YORK
#
#                      City State          Zip  Amount  Memo_CD  Match Amount
# 0               HOCKESSIN    DE  197071618.0     500      NaN         100.0
# 1  PORT JEFFERSON STATION    NY  117764286.0     250      NaN           0.0
# 2           WILLIAMSVILLE    NY      14221.0     250      NaN           0.0
# 3                NEW YORK    NY      10023.0    1000      NaN           0.0
# 4                 BUFFALO    NY      14214.0     250      NaN           0.0

# %%
# Finally, apply can also be used with lambda functions.

donors_df['Match Amount'] = donors_df['Amount'].apply(lambda x: x * 0.1 if x < 500 else x * 0.2)
donors_df.head()
# Out:
#                                Name                      Employer  \
# 0                      CAREY, JAMES                  NOT EMPLOYED
# 1                    OBICI, SILVANA                   STONY BROOK
# 2                    MAISLIN, KAREN                       RETIRED
# 3  MCCLELLAND, CARTER AND STEPHANIE         UNION SQUARE ADVISORS
# 4                 MCCLUSKEY, MARTHA  STATE UNIVERSITY OF NEW YORK
#
#                      City State          Zip  Amount  Memo_CD  Match Amount
# 0               HOCKESSIN    DE  197071618.0     500      NaN         100.0
# 1  PORT JEFFERSON STATION    NY  117764286.0     250      NaN          25.0
# 2           WILLIAMSVILLE    NY      14221.0     250      NaN          25.0
# 3                NEW YORK    NY      10023.0    1000      NaN         200.0
# 4                 BUFFALO    NY      14214.0     250      NaN          25.0
